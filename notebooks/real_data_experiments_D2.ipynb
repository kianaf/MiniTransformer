# %%
import torch
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
# torch.multiprocessing.set_start_method('spawn', force=True)
import time
import importlib
import torch.optim as optim
from torchsummary import summary
import os
import statistics

os.chdir("../")
from src.data_preparation import SimulatedDataset, collate_function, load_real_data
from src.transformers import MiniTransformer
import src.transformers as transformerFunctions
from src.transformers import init_weights_recursive
from src.transformers import print_parameters
from src.transformers import create_custom_mask_pair, create_custom_mask_pred, create_distance_to_end_matrix, create_pairwise_distance_matrix
from src.evaluation import calculate_bench1_loss, calculate_bench2_loss, calculate_repeat_loss, calculate_regression_loss, evaluate_mini_transformer
from src.statistical_testing import statistical_testing, print_p_values, plot_context_predindex_pair_effect, get_context_predindex_pair_effect
import torch.autograd.profiler as profiler
from sklearn.model_selection import KFold
device = torch.device("cpu")

# %%
data_str = "ghq_sum"
data, maxlen = load_real_data(data_str)

# get number of sequences
print(f"Number of sequences: {len(data)}")

# get min, max, median of sequence length
seq_lengths = [len(seq) for seq in data]
print(f"Minimum sequence length: {min(seq_lengths)}")
print(f"Maximum sequence length: {max(seq_lengths)}")
print(f"Median sequence length: {statistics.median(seq_lengths)}")
# Out:
# Number of sequences: 878
# Minimum sequence length: 3
# Maximum sequence length: 20
# Median sequence length: 13.0

# %%
if __name__ == '__main__':
    
    bench_repeat_loss_list = []
    regression_loss_total_list = []
    model_loss_total_list = []
    regression_loss_predindex_list = []
    model_loss_predindex_list = []
    bench1_loss_list = []
    bench2_loss_list = []
    bench2loss_predindex_list = []
    bench_repeat_loss_predindex_list = []
    benchloss_predindex_list = []
    models = []
    


    # Hyperparameters
    # data_str = "ghq_b_sum"
    data_str = "ghq_sum"
    # data_str = "simulation"
    batch_size = 2          # Batch size for loading data
    dk = 1                  # d_k
    dv = 1                  # d_v
    nheads = 8             # number of heads
    ncum = 8                 # number of cumulants
    maxlen = 10             # maximum length of the sequence
    learning_rate = 1e-3
    lambda_l2 = 1e-3
    EPOCHS = 150
    target_sample_size = 8
    nrepp = 10
    seeds = [0, 1, 11, 42, 123, 999, 1337, 2025, 9999, 12345]
    
    k_for_cross_val = 10
    
    # load real data
    data, maxlen = load_real_data(data_str)
    
    
    # Create the KFold splitter:
    kf = KFold(n_splits=k_for_cross_val, shuffle=True, random_state=42)

    # Build a list of (train, eval) folds:
    folds = []
    for train_index, eval_index in kf.split(data):
        train_data = [data[i] for i in train_index]
        eval_data  = [data[i] for i in eval_index]
        folds.append((train_data, eval_data))
    
    
    cnt = 0
    for (train, val) in folds:
        
        # Set the random seed for reproducibility
        torch.manual_seed(seeds[cnt])
        cnt += 1

        
        n = len(train)
        p = train[0].shape[1]
        print("Train size: ", len(train), "\n")
        print("Val size: ", len(val), "\n")
        
        train_dataset = train
        eval_dataset = val
        predindex = 9


        mask_pairwise = create_custom_mask_pair(maxlen, device)
        distance_to_end_matrix = create_distance_to_end_matrix(maxlen, device)
        pairwise_distance_matrix = create_pairwise_distance_matrix(maxlen, device)

    
        dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_function,  num_workers=0)
        eval_dataloader = DataLoader(eval_dataset, batch_size=len(eval_dataset), shuffle=False, collate_fn=collate_function, num_workers=0)
       
       
        model = MiniTransformer(p, nheads, dk, dv, ncum, mask_pairwise, pairwise_distance_matrix, distance_to_end_matrix,  device)

        # model.apply(init_weights_recursive)
        model.to(device)

        # model = torch.compile(model)
        # Start the timer
        start_time = time.time()

        # Define optimizer
        # optimizer = optim.Adam(model.parameters(), lr= learning_rate, weight_decay=lambda_l2)
        optimizer = optim.Adam(model.parameters(), lr= learning_rate)
        
        print("Number of Parameters", transformerFunctions.count_parameters(model))
        
        run_path = transformerFunctions.train_mini_transformer(model, dataloader, eval_dataloader, optimizer, lambda_l2, EPOCHS, device)


        # # Enable profiling
        # with profiler.profile() as prof:

        #     model.eval() 
        #     # Forward pass
        #     output = model(train_dataset.data)
        #     # Backward pass (this will profile the backward pass as well)
        #     output.backward(torch.ones_like(output))

        # # Print profiling results
        # print(prof.key_averages().table(sort_by="cpu_time_total", row_limit=10))



        # End the timer
        end_time = time.time()

        # Calculate and print the execution time
        execution_time = end_time - start_time 
        print(f"Execution time: {execution_time:.6f} seconds")


        
        
        
        # Evaluate the model
        
        eval_dataloader = DataLoader(eval_dataset, batch_size=1, shuffle=False, collate_fn=collate_function, num_workers=0)
       
    
    
        dimave, bench1_loss, benchloss_predindex = calculate_bench1_loss(train_dataset, eval_dataset, predindex)
        regression_loss_predindex, regression_loss_total = calculate_regression_loss(train_dataset, eval_dataset, predindex)
        model_loss_predindex, model_loss_total = evaluate_mini_transformer(eval_dataloader, model, predindex)
        
        
        print("baseline average loss: ", bench1_loss)

        
        # Evaluate the model
        if data_str == "simulation":
            bench2loss, bench2loss_predindex = calculate_bench2_loss(train_dataset, eval_dataset, dimave)
            print("baseline informed loss: ", bench2loss)
            bench2_loss_list.append(bench2loss)
            bench2loss_predindex_list.append(bench2loss_predindex)
            
        else:
            bench_repeat, bench_repeat_predindex = calculate_repeat_loss(eval_dataset, predindex)    
            print("baseline repeat: ", bench_repeat)
            
            
            
        print("regression loss total: ", regression_loss_total)
        print("model loss total: ", model_loss_total.item(), "\n") 
        
        
        if data_str == "simulation":
            print("baseline informed loss predindex: ", bench2loss_predindex)
            bench2loss_predindex_list.append(bench2loss_predindex)
            
        print("baseline average loss predindex: ", benchloss_predindex)
        print("baseline repeat predindex: ", bench_repeat_predindex)    
        print("regression loss predindex: ", regression_loss_predindex)
        print("model loss predindex: ", model_loss_predindex.item()) 


        
        
        bench_repeat_loss_list.append(bench_repeat)
        regression_loss_total_list.append(regression_loss_total)
        model_loss_total_list.append(model_loss_total.item())
        benchloss_predindex_list.append(benchloss_predindex)
        bench_repeat_loss_predindex_list.append(bench_repeat_predindex)
        regression_loss_predindex_list.append(regression_loss_predindex)
        model_loss_predindex_list.append(model_loss_predindex.item())
        bench1_loss_list.append(bench1_loss)
        
        
        
# save the mean and std of these lists in text file in the format of mean ± std 
# os.chdir("./notebooks/results")




with open(f"./notebooks/pred_{data_str}_results_n={n}_batch_size={batch_size}_p={p}_ncum={ncum}_nheads={nheads}_epochs={EPOCHS}.txt", "a") as f:
    # First line
    f.write(f"{data_str} results n = {n}\n")

    # Single-line writes with three-decimal formatting:
    f.write(f"baseline repeat: {statistics.mean(bench_repeat_loss_list):.3f} ± {statistics.stdev(bench_repeat_loss_list):.3f}\n")
    f.write(f"baseline average loss: {statistics.mean(bench1_loss_list):.3f} ± {statistics.stdev(bench1_loss_list):.3f}\n")
    if data_str == "simulation":
        f.write(f"baseline informed loss: {statistics.mean(bench2_loss_list):.3f} ± {statistics.stdev(bench2_loss_list):.3f}\n")
        
    f.write(f"regression loss total: {statistics.mean(regression_loss_total_list):.3f} ± {statistics.stdev(regression_loss_total_list):.3f}\n")
    f.write(f"model loss total: {statistics.mean(model_loss_total_list):.3f} ± {statistics.stdev(model_loss_total_list):.3f}\n\n")

    
    f.write(f"baseline repeat predindex: {statistics.mean(bench_repeat_loss_predindex_list):.3f} ± {statistics.stdev(bench_repeat_loss_list):.3f}\n")
    f.write(f"baseline average loss predindex: {statistics.mean(benchloss_predindex_list):.3f} ± {statistics.stdev(benchloss_predindex_list):.3f}\n")
    f.write(f"regression loss predindex: {statistics.mean(regression_loss_predindex_list):.3f} ± {statistics.stdev(regression_loss_predindex_list):.3f}\n")
    if data_str == "simulation":
        f.write(f"baseline informed loss predindex: {statistics.mean(bench2loss_predindex_list):.3f} ± {statistics.stdev(bench2loss_predindex_list):.3f}\n")
    f.write(f"model loss predindex: {statistics.mean(model_loss_predindex_list):.3f} ± {statistics.stdev(model_loss_predindex_list):.3f}\n")

    # Extra newlines at the end
    f.write("\n\n")
# Out:
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss:     17.71513 penalty    : 0.01143
# avg_loss_val: 14.24196 penalty_val: 0.01143
# EPOCH 11:
# avg_loss:     12.53235 penalty    : 0.02048
# avg_loss_val: 13.07588 penalty_val: 0.02049
# EPOCH 21:
# avg_loss:     12.30148 penalty    : 0.02397
# avg_loss_val: 12.84218 penalty_val: 0.02397
# EPOCH 31:
# avg_loss:     12.28318 penalty    : 0.02598
# avg_loss_val: 12.74968 penalty_val: 0.02598
# EPOCH 41:
# avg_loss:     12.25578 penalty    : 0.02748
# avg_loss_val: 12.73340 penalty_val: 0.02748
# EPOCH 51:
# avg_loss:     12.25715 penalty    : 0.02881
# avg_loss_val: 12.72703 penalty_val: 0.02880
# EPOCH 61:
# avg_loss:     12.00650 penalty    : 0.03182
# avg_loss_val: 12.39548 penalty_val: 0.03182
# EPOCH 71:
# avg_loss:     11.94131 penalty    : 0.03486
# avg_loss_val: 12.37994 penalty_val: 0.03486
# EPOCH 81:
# avg_loss:     11.92789 penalty    : 0.03727
# avg_loss_val: 12.32594 penalty_val: 0.03727
# EPOCH 91:
# avg_loss:     11.92504 penalty    : 0.03934
# avg_loss_val: 12.32388 penalty_val: 0.03934
# EPOCH 101:
# avg_loss:     11.91018 penalty    : 0.04116
# avg_loss_val: 12.35540 penalty_val: 0.04115
# EPOCH 111:
# avg_loss:     11.91092 penalty    : 0.04270
# avg_loss_val: 12.36085 penalty_val: 0.04270
# EPOCH 121:
# avg_loss:     11.90989 penalty    : 0.04396
# avg_loss_val: 12.31649 penalty_val: 0.04396
# EPOCH 131:
# avg_loss:     11.90213 penalty    : 0.04490
# avg_loss_val: 12.30980 penalty_val: 0.04490
# EPOCH 141:
# avg_loss:     11.89924 penalty    : 0.04531
# avg_loss_val: 12.32931 penalty_val: 0.04531
# Execution time: 107.212012 seconds
# baseline average loss:  0.15810970805416052
# baseline repeat:  0.21477273148907858
# regression loss total:  0.14276478477855387
# model loss total:  0.1339787393808365
#
# baseline average loss predindex:  0.2242332019589164
# baseline repeat predindex:  0.2840909090909091
# regression loss predindex:  0.1904359268614326
# model loss predindex:  0.17500987648963928
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss:     17.55370 penalty    : 0.01471
# avg_loss_val: 13.41172 penalty_val: 0.01471
# EPOCH 11:
# avg_loss:     12.32002 penalty    : 0.02552
# avg_loss_val: 11.91964 penalty_val: 0.02551
# EPOCH 21:
# avg_loss:     12.12459 penalty    : 0.03099
# avg_loss_val: 11.75877 penalty_val: 0.03100
# EPOCH 31:
# avg_loss:     12.04625 penalty    : 0.03424
# avg_loss_val: 11.72309 penalty_val: 0.03424
# EPOCH 41:
# avg_loss:     12.01860 penalty    : 0.03647
# avg_loss_val: 11.65185 penalty_val: 0.03647
# EPOCH 51:
# avg_loss:     12.00874 penalty    : 0.03789
# avg_loss_val: 11.62910 penalty_val: 0.03788
# EPOCH 61:
# avg_loss:     12.00066 penalty    : 0.03856
# avg_loss_val: 11.65385 penalty_val: 0.03856
# EPOCH 71:
# avg_loss:     11.99271 penalty    : 0.03918
# avg_loss_val: 11.63651 penalty_val: 0.03918
# EPOCH 81:
# avg_loss:     11.98958 penalty    : 0.03973
# avg_loss_val: 11.63371 penalty_val: 0.03973
# EPOCH 91:
# avg_loss:     11.98746 penalty    : 0.04017
# avg_loss_val: 11.64541 penalty_val: 0.04018
# EPOCH 101:
# avg_loss:     11.98533 penalty    : 0.04046
# avg_loss_val: 11.62123 penalty_val: 0.04047
# EPOCH 111:
# avg_loss:     11.97827 penalty    : 0.04073
# avg_loss_val: 11.65252 penalty_val: 0.04072
# EPOCH 121:
# avg_loss:     11.97546 penalty    : 0.04111
# avg_loss_val: 11.62283 penalty_val: 0.04111
# EPOCH 131:
# avg_loss:     11.97068 penalty    : 0.04141
# avg_loss_val: 11.65934 penalty_val: 0.04142
# EPOCH 141:
# avg_loss:     11.96967 penalty    : 0.04154
# avg_loss_val: 11.63949 penalty_val: 0.04154
# Execution time: 115.098154 seconds
# baseline average loss:  0.1449389202012257
# baseline repeat:  0.18068182205950672
# regression loss total:  0.121073489383054
# model loss total:  0.10906258225440979
#
# baseline average loss predindex:  0.19835770672017877
# baseline repeat predindex:  0.1590909090909091
# regression loss predindex:  0.1363007399193434
# model loss predindex:  0.13040880858898163
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss:     18.16005 penalty    : 0.01231
# avg_loss_val: 12.65529 penalty_val: 0.01232
# EPOCH 11:
# avg_loss:     12.59122 penalty    : 0.01924
# avg_loss_val: 11.83065 penalty_val: 0.01924
# EPOCH 21:
# avg_loss:     12.45397 penalty    : 0.02274
# avg_loss_val: 11.70574 penalty_val: 0.02274
# EPOCH 31:
# avg_loss:     12.40830 penalty    : 0.02495
# avg_loss_val: 11.67871 penalty_val: 0.02495
# EPOCH 41:
# avg_loss:     12.39016 penalty    : 0.02658
# avg_loss_val: 11.64336 penalty_val: 0.02658
# EPOCH 51:
# avg_loss:     12.38154 penalty    : 0.02797
# avg_loss_val: 11.67011 penalty_val: 0.02797
# EPOCH 61:
# avg_loss:     12.36196 penalty    : 0.02880
# avg_loss_val: 11.63269 penalty_val: 0.02880
# EPOCH 71:
# avg_loss:     12.34122 penalty    : 0.02920
# avg_loss_val: 11.60614 penalty_val: 0.02920
# EPOCH 81:
# avg_loss:     12.32897 penalty    : 0.03028
# avg_loss_val: 11.59831 penalty_val: 0.03028
# EPOCH 91:
# avg_loss:     12.32272 penalty    : 0.03115
# avg_loss_val: 11.61423 penalty_val: 0.03115
# EPOCH 101:
# avg_loss:     12.31333 penalty    : 0.03197
# avg_loss_val: 11.60595 penalty_val: 0.03197
# EPOCH 111:
# avg_loss:     12.30617 penalty    : 0.03281
# avg_loss_val: 11.62015 penalty_val: 0.03281
# EPOCH 121:
# avg_loss:     12.29567 penalty    : 0.03312
# avg_loss_val: 11.60919 penalty_val: 0.03312
# EPOCH 131:
# avg_loss:     12.30126 penalty    : 0.03357
# avg_loss_val: 11.56883 penalty_val: 0.03357
# EPOCH 141:
# avg_loss:     12.28905 penalty    : 0.03385
# avg_loss_val: 11.57719 penalty_val: 0.03385
# Execution time: 75.473887 seconds
# baseline average loss:  0.14954213992777196
# baseline repeat:  0.23068182297389617
# regression loss total:  0.1358609797984465
# model loss total:  0.13353057205677032
#
# baseline average loss predindex:  0.19834709709340875
# baseline repeat predindex:  0.3522727272727273
# regression loss predindex:  0.20026124068018383
# model loss predindex:  0.20791859924793243
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss:     17.34117 penalty    : 0.01601
# avg_loss_val: 14.27832 penalty_val: 0.01601
# EPOCH 11:
# avg_loss:     12.31493 penalty    : 0.02308
# avg_loss_val: 12.97237 penalty_val: 0.02308
# EPOCH 21:
# avg_loss:     12.06328 penalty    : 0.03028
# avg_loss_val: 12.72278 penalty_val: 0.03028
# EPOCH 31:
# avg_loss:     11.96617 penalty    : 0.03520
# avg_loss_val: 12.64947 penalty_val: 0.03519
# EPOCH 41:
# avg_loss:     11.93849 penalty    : 0.03821
# avg_loss_val: 12.63623 penalty_val: 0.03821
# EPOCH 51:
# avg_loss:     11.93177 penalty    : 0.04003
# avg_loss_val: 12.65014 penalty_val: 0.04002
# EPOCH 61:
# avg_loss:     11.91259 penalty    : 0.04155
# avg_loss_val: 12.63099 penalty_val: 0.04155
# EPOCH 71:
# avg_loss:     11.91461 penalty    : 0.04256
# avg_loss_val: 12.61648 penalty_val: 0.04257
# EPOCH 81:
# avg_loss:     11.89962 penalty    : 0.04333
# avg_loss_val: 12.61047 penalty_val: 0.04333
# EPOCH 91:
# avg_loss:     11.90087 penalty    : 0.04384
# avg_loss_val: 12.61860 penalty_val: 0.04384
# EPOCH 101:
# avg_loss:     11.89508 penalty    : 0.04429
# avg_loss_val: 12.64800 penalty_val: 0.04430
# EPOCH 111:
# avg_loss:     11.89549 penalty    : 0.04452
# avg_loss_val: 12.61589 penalty_val: 0.04453
# EPOCH 121:
# avg_loss:     11.89353 penalty    : 0.04467
# avg_loss_val: 12.65556 penalty_val: 0.04466
# EPOCH 131:
# avg_loss:     11.88314 penalty    : 0.04481
# avg_loss_val: 12.65148 penalty_val: 0.04482
# EPOCH 141:
# avg_loss:     11.88099 penalty    : 0.04511
# avg_loss_val: 12.63521 penalty_val: 0.04511
# Execution time: 66.553535 seconds
# baseline average loss:  0.15762824908068235
# baseline repeat:  0.23863636829297652
# regression loss total:  0.14877931341633457
# model loss total:  0.13651035726070404
#
# baseline average loss predindex:  0.22364903520792723
# baseline repeat predindex:  0.32954545454545453
# regression loss predindex:  0.21317685548804696
# model loss predindex:  0.20776046812534332
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss:     17.28095 penalty    : 0.01207
# avg_loss_val: 14.07932 penalty_val: 0.01207
# EPOCH 11:
# avg_loss:     12.43608 penalty    : 0.02186
# avg_loss_val: 13.04314 penalty_val: 0.02186
# EPOCH 21:
# avg_loss:     12.35640 penalty    : 0.02355
# avg_loss_val: 12.94066 penalty_val: 0.02355
# EPOCH 31:
# avg_loss:     12.31710 penalty    : 0.02478
# avg_loss_val: 12.87810 penalty_val: 0.02478
# EPOCH 41:
# avg_loss:     12.28094 penalty    : 0.02601
# avg_loss_val: 12.82257 penalty_val: 0.02601
# EPOCH 51:
# avg_loss:     12.24529 penalty    : 0.02682
# avg_loss_val: 12.79431 penalty_val: 0.02681
# EPOCH 61:
# avg_loss:     12.23262 penalty    : 0.02781
# avg_loss_val: 12.77794 penalty_val: 0.02780
# EPOCH 71:
# avg_loss:     12.22499 penalty    : 0.02863
# avg_loss_val: 12.78164 penalty_val: 0.02863
# EPOCH 81:
# avg_loss:     12.21348 penalty    : 0.02925
# avg_loss_val: 12.78112 penalty_val: 0.02924
# EPOCH 91:
# avg_loss:     12.20093 penalty    : 0.02957
# avg_loss_val: 12.76005 penalty_val: 0.02958
# EPOCH 101:
# avg_loss:     12.19750 penalty    : 0.02992
# avg_loss_val: 12.80582 penalty_val: 0.02992
# EPOCH 111:
# avg_loss:     12.19620 penalty    : 0.02999
# avg_loss_val: 12.76860 penalty_val: 0.03000
# EPOCH 121:
# avg_loss:     12.19053 penalty    : 0.03021
# avg_loss_val: 12.78399 penalty_val: 0.03021
# EPOCH 131:
# avg_loss:     12.17226 penalty    : 0.03001
# avg_loss_val: 12.77805 penalty_val: 0.03002
# EPOCH 141:
# avg_loss:     12.16450 penalty    : 0.03014
# avg_loss_val: 12.75020 penalty_val: 0.03013
# Execution time: 66.891403 seconds
# baseline average loss:  0.14869980988177386
# baseline repeat:  0.18295454962009733
# regression loss total:  0.1261951253998941
# model loss total:  0.1258005052804947
#
# baseline average loss predindex:  0.19327347793362357
# baseline repeat predindex:  0.32954545454545453
# regression loss predindex:  0.18515294761453258
# model loss predindex:  0.18769069015979767
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss:     18.80124 penalty    : 0.01808
# avg_loss_val: 12.70760 penalty_val: 0.01809
# EPOCH 11:
# avg_loss:     12.26038 penalty    : 0.02988
# avg_loss_val: 11.54605 penalty_val: 0.02987
# EPOCH 21:
# avg_loss:     12.13820 penalty    : 0.03405
# avg_loss_val: 11.47358 penalty_val: 0.03404
# EPOCH 31:
# avg_loss:     12.09732 penalty    : 0.03622
# avg_loss_val: 11.46868 penalty_val: 0.03622
# EPOCH 41:
# avg_loss:     12.07711 penalty    : 0.03802
# avg_loss_val: 11.46672 penalty_val: 0.03803
# EPOCH 51:
# avg_loss:     12.06230 penalty    : 0.03989
# avg_loss_val: 11.50006 penalty_val: 0.03988
# EPOCH 61:
# avg_loss:     12.04959 penalty    : 0.04113
# avg_loss_val: 11.44628 penalty_val: 0.04113
# EPOCH 71:
# avg_loss:     12.03152 penalty    : 0.04214
# avg_loss_val: 11.48097 penalty_val: 0.04216
# EPOCH 81:
# avg_loss:     12.03163 penalty    : 0.04272
# avg_loss_val: 11.47781 penalty_val: 0.04272
# EPOCH 91:
# avg_loss:     12.02849 penalty    : 0.04305
# avg_loss_val: 11.43394 penalty_val: 0.04306
# EPOCH 101:
# avg_loss:     12.01821 penalty    : 0.04333
# avg_loss_val: 11.43290 penalty_val: 0.04332
# EPOCH 111:
# avg_loss:     12.01972 penalty    : 0.04331
# avg_loss_val: 11.43250 penalty_val: 0.04331
# EPOCH 121:
# avg_loss:     12.01050 penalty    : 0.04351
# avg_loss_val: 11.43165 penalty_val: 0.04351
# EPOCH 131:
# avg_loss:     12.01947 penalty    : 0.04357
# avg_loss_val: 11.40401 penalty_val: 0.04356
# EPOCH 141:
# avg_loss:     12.01259 penalty    : 0.04382
# avg_loss_val: 11.39976 penalty_val: 0.04382
# Execution time: 65.269784 seconds
# baseline average loss:  0.1491056949916211
# baseline repeat:  0.2261363681913777
# regression loss total:  0.137947379549421
# model loss total:  0.12881682813167572
#
# baseline average loss predindex:  0.20343456806784327
# baseline repeat predindex:  0.26136363636363635
# regression loss predindex:  0.17850801415634893
# model loss predindex:  0.17984816431999207
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss:     16.72635 penalty    : 0.01614
# avg_loss_val: 13.17263 penalty_val: 0.01614
# EPOCH 11:
# avg_loss:     12.57639 penalty    : 0.02103
# avg_loss_val: 12.35114 penalty_val: 0.02104
# EPOCH 21:
# avg_loss:     12.41202 penalty    : 0.02406
# avg_loss_val: 12.25207 penalty_val: 0.02407
# EPOCH 31:
# avg_loss:     12.38095 penalty    : 0.02557
# avg_loss_val: 12.18330 penalty_val: 0.02557
# EPOCH 41:
# avg_loss:     12.32021 penalty    : 0.02744
# avg_loss_val: 12.18840 penalty_val: 0.02745
# EPOCH 51:
# avg_loss:     12.06177 penalty    : 0.03085
# avg_loss_val: 11.86669 penalty_val: 0.03086
# EPOCH 61:
# avg_loss:     12.03176 penalty    : 0.03415
# avg_loss_val: 11.84600 penalty_val: 0.03414
# EPOCH 71:
# avg_loss:     12.00753 penalty    : 0.03766
# avg_loss_val: 11.80681 penalty_val: 0.03765
# EPOCH 81:
# avg_loss:     11.99446 penalty    : 0.03983
# avg_loss_val: 11.80897 penalty_val: 0.03983
# EPOCH 91:
# avg_loss:     11.98875 penalty    : 0.04105
# avg_loss_val: 11.81006 penalty_val: 0.04105
# EPOCH 101:
# avg_loss:     11.97980 penalty    : 0.04188
# avg_loss_val: 11.86429 penalty_val: 0.04187
# EPOCH 111:
# avg_loss:     11.96174 penalty    : 0.04232
# avg_loss_val: 11.87337 penalty_val: 0.04232
# EPOCH 121:
# avg_loss:     11.96283 penalty    : 0.04287
# avg_loss_val: 11.81789 penalty_val: 0.04287
# EPOCH 131:
# avg_loss:     11.95233 penalty    : 0.04327
# avg_loss_val: 11.86414 penalty_val: 0.04327
# EPOCH 141:
# avg_loss:     11.95269 penalty    : 0.04359
# avg_loss_val: 11.82741 penalty_val: 0.04359
# Execution time: 66.994566 seconds
# baseline average loss:  0.14667171163653786
# baseline repeat:  0.22500000419941815
# regression loss total:  0.13874017527501298
# model loss total:  0.13378988206386566
#
# baseline average loss predindex:  0.24414468742907047
# baseline repeat predindex:  0.2727272727272727
# regression loss predindex:  0.20511598438644646
# model loss predindex:  0.21009664237499237
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss:     18.19943 penalty    : 0.01587
# avg_loss_val: 12.55849 penalty_val: 0.01586
# EPOCH 11:
# avg_loss:     12.28983 penalty    : 0.02744
# avg_loss_val: 11.51397 penalty_val: 0.02744
# EPOCH 21:
# avg_loss:     12.11766 penalty    : 0.03361
# avg_loss_val: 11.36543 penalty_val: 0.03360
# EPOCH 31:
# avg_loss:     12.06486 penalty    : 0.03642
# avg_loss_val: 11.34271 penalty_val: 0.03642
# EPOCH 41:
# avg_loss:     12.04397 penalty    : 0.03802
# avg_loss_val: 11.37740 penalty_val: 0.03803
# EPOCH 51:
# avg_loss:     12.03431 penalty    : 0.03938
# avg_loss_val: 11.37268 penalty_val: 0.03938
# EPOCH 61:
# avg_loss:     12.02875 penalty    : 0.04026
# avg_loss_val: 11.35684 penalty_val: 0.04027
# EPOCH 71:
# avg_loss:     12.02123 penalty    : 0.04118
# avg_loss_val: 11.33708 penalty_val: 0.04118
# EPOCH 81:
# avg_loss:     12.01547 penalty    : 0.04169
# avg_loss_val: 11.36020 penalty_val: 0.04169
# EPOCH 91:
# avg_loss:     12.01556 penalty    : 0.04201
# avg_loss_val: 11.34400 penalty_val: 0.04200
# EPOCH 101:
# avg_loss:     12.01045 penalty    : 0.04245
# avg_loss_val: 11.34636 penalty_val: 0.04245
# EPOCH 111:
# avg_loss:     12.00506 penalty    : 0.04262
# avg_loss_val: 11.35739 penalty_val: 0.04262
# EPOCH 121:
# avg_loss:     12.00698 penalty    : 0.04282
# avg_loss_val: 11.38852 penalty_val: 0.04282
# EPOCH 131:
# avg_loss:     12.00899 penalty    : 0.04278
# avg_loss_val: 11.35088 penalty_val: 0.04278
# EPOCH 141:
# avg_loss:     11.99881 penalty    : 0.04281
# avg_loss_val: 11.35422 penalty_val: 0.04280
# Execution time: 66.444363 seconds
# baseline average loss:  0.1464615726674145
# baseline repeat:  0.2125000050291419
# regression loss total:  0.13619163716746993
# model loss total:  0.12805145978927612
#
# baseline average loss predindex:  0.19836191155693747
# baseline repeat predindex:  0.32954545454545453
# regression loss predindex:  0.19736180993940725
# model loss predindex:  0.17393611371517181
# Train size:  791
#
# Val size:  87
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss:     20.02944 penalty    : 0.01182
# avg_loss_val: 13.94592 penalty_val: 0.01182
# EPOCH 11:
# avg_loss:     12.39642 penalty    : 0.02197
# avg_loss_val: 12.85192 penalty_val: 0.02196
# EPOCH 21:
# avg_loss:     12.35487 penalty    : 0.02403
# avg_loss_val: 12.69939 penalty_val: 0.02403
# EPOCH 31:
# avg_loss:     12.32218 penalty    : 0.02517
# avg_loss_val: 12.67945 penalty_val: 0.02516
# EPOCH 41:
# avg_loss:     12.32151 penalty    : 0.02613
# avg_loss_val: 12.69172 penalty_val: 0.02614
# EPOCH 51:
# avg_loss:     12.30105 penalty    : 0.02734
# avg_loss_val: 12.70184 penalty_val: 0.02734
# EPOCH 61:
# avg_loss:     12.31390 penalty    : 0.02834
# avg_loss_val: 12.67730 penalty_val: 0.02834
# EPOCH 71:
# avg_loss:     12.30688 penalty    : 0.02944
# avg_loss_val: 12.73476 penalty_val: 0.02944
# EPOCH 81:
# avg_loss:     12.29418 penalty    : 0.03071
# avg_loss_val: 12.64347 penalty_val: 0.03071
# EPOCH 91:
# avg_loss:     11.99779 penalty    : 0.03393
# avg_loss_val: 12.46055 penalty_val: 0.03393
# EPOCH 101:
# avg_loss:     11.98390 penalty    : 0.03572
# avg_loss_val: 12.45735 penalty_val: 0.03571
# EPOCH 111:
# avg_loss:     11.96765 penalty    : 0.03730
# avg_loss_val: 12.40141 penalty_val: 0.03731
# EPOCH 121:
# avg_loss:     11.95947 penalty    : 0.03884
# avg_loss_val: 12.42276 penalty_val: 0.03883
# EPOCH 131:
# avg_loss:     11.96266 penalty    : 0.04022
# avg_loss_val: 12.40162 penalty_val: 0.04021
# EPOCH 141:
# avg_loss:     11.94995 penalty    : 0.04113
# avg_loss_val: 12.37511 penalty_val: 0.04112
# Execution time: 69.261357 seconds
# baseline average loss:  0.13948089578028383
# baseline repeat:  0.19540230364635072
# regression loss total:  0.12597633930704782
# model loss total:  0.1166057363152504
#
# baseline average loss predindex:  0.2153423767665337
# baseline repeat predindex:  0.367816091954023
# regression loss predindex:  0.21619645753763092
# model loss predindex:  0.1937812864780426
# Train size:  791
#
# Val size:  87
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss:     16.86809 penalty    : 0.01060
# avg_loss_val: 14.37964 penalty_val: 0.01060
# EPOCH 11:
# avg_loss:     12.42881 penalty    : 0.02036
# avg_loss_val: 13.28114 penalty_val: 0.02036
# EPOCH 21:
# avg_loss:     12.34436 penalty    : 0.02215
# avg_loss_val: 13.23732 penalty_val: 0.02216
# EPOCH 31:
# avg_loss:     12.31123 penalty    : 0.02361
# avg_loss_val: 13.19750 penalty_val: 0.02360
# EPOCH 41:
# avg_loss:     12.28603 penalty    : 0.02526
# avg_loss_val: 13.14460 penalty_val: 0.02528
# EPOCH 51:
# avg_loss:     11.94471 penalty    : 0.03018
# avg_loss_val: 12.90351 penalty_val: 0.03018
# EPOCH 61:
# avg_loss:     11.90252 penalty    : 0.03331
# avg_loss_val: 12.91197 penalty_val: 0.03331
# EPOCH 71:
# avg_loss:     11.89419 penalty    : 0.03619
# avg_loss_val: 12.86785 penalty_val: 0.03621
# EPOCH 81:
# avg_loss:     11.88210 penalty    : 0.03842
# avg_loss_val: 12.86394 penalty_val: 0.03843
# EPOCH 91:
# avg_loss:     11.87143 penalty    : 0.03983
# avg_loss_val: 12.83269 penalty_val: 0.03982
# EPOCH 101:
# avg_loss:     11.85580 penalty    : 0.04061
# avg_loss_val: 12.84964 penalty_val: 0.04061
# EPOCH 111:
# avg_loss:     11.86461 penalty    : 0.04111
# avg_loss_val: 12.87187 penalty_val: 0.04111
# EPOCH 121:
# avg_loss:     11.86293 penalty    : 0.04183
# avg_loss_val: 12.82070 penalty_val: 0.04184
# EPOCH 131:
# avg_loss:     11.84988 penalty    : 0.04229
# avg_loss_val: 12.83911 penalty_val: 0.04229
# EPOCH 141:
# avg_loss:     11.84430 penalty    : 0.04274
# avg_loss_val: 12.81499 penalty_val: 0.04273
# Execution time: 66.247312 seconds
# baseline average loss:  0.14444225581212974
# baseline repeat:  0.20919540592993813
# regression loss total:  0.13684807552689016
# model loss total:  0.12883740663528442
#
# baseline average loss predindex:  0.1843934953212738
# baseline repeat predindex:  0.2988505747126437
# regression loss predindex:  0.1822520095995293
# model loss predindex:  0.1585264503955841
