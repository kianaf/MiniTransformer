# %%
import torch
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
# torch.multiprocessing.set_start_method('spawn', force=True)
import time
import importlib
import torch.optim as optim
from torchsummary import summary
import os
import statistics

os.chdir("../")
from src.data_preparation import SimulatedDataset, collate_function, load_real_data
from src.transformers import MiniTransformer
import src.transformers as transformerFunctions
from src.transformers import init_weights_recursive
from src.transformers import print_parameters
from src.transformers import create_custom_mask, create_distance_to_end_matrix, create_pairwise_distance_matrix
from src.evaluation import calculate_bench1_loss, calculate_bench2_loss, calculate_repeat_loss, calculate_regression_loss, evaluate_mini_transformer
from src.statistical_testing import statistical_testing, print_p_values, plot_context_predindex_pair_effect, get_context_predindex_pair_effect
import torch.autograd.profiler as profiler
from sklearn.model_selection import KFold
device = torch.device("cpu")

# %%
if __name__ == '__main__':
    
    bench_repeat_loss_list = []
    regression_loss_total_list = []
    model_loss_total_list = []
    regression_loss_predindex_list = []
    model_loss_predindex_list = []
    bench1_loss_list = []
    bench2_loss_list = []
    bench2loss_predindex_list = []
    bench_repeat_loss_predindex_list = []
    benchloss_predindex_list = []
    models = []
    


    # Hyperparameters
    # data_str = "ghq_b_sum"
    data_str = "ghq_sum"
    # data_str = "simulation"
    batch_size = 1          # Batch size for loading data
    dk = 1                  # d_k
    dv = 1                  # d_v
    nheads = 4             # number of heads
    ncum = 8                 # number of cumulants
    maxlen = 10             # maximum length of the sequence
    learning_rate = 1e-3
    lambda_l2 = 1e-3
    EPOCHS = 100
    target_sample_size = 7
    nrepp = 10
    seeds = [0, 1, 11, 42, 123, 999, 1337, 2025, 9999, 12345]
    
    k_for_cross_val = 10
    
    # load real data
    data, maxlen = load_real_data(data_str)
    
    
    # Create the KFold splitter:
    kf = KFold(n_splits=k_for_cross_val, shuffle=True, random_state=42)

    # Build a list of (train, eval) folds:
    folds = []
    for train_index, eval_index in kf.split(data):
        train_data = [data[i] for i in train_index]
        eval_data  = [data[i] for i in eval_index]
        folds.append((train_data, eval_data))
    
    
    
    for (train, val) in folds:
        
        # Set the random seed for reproducibility
        torch.manual_seed(42)


        
        n = len(train)
        p = train[0].shape[1]
        print("Train size: ", len(train), "\n")
        print("Val size: ", len(val), "\n")
        
        train_dataset = train
        eval_dataset = val
        predindex = 9

        

        mask = create_custom_mask(maxlen, device)
        distance_to_end_matrix = create_distance_to_end_matrix(maxlen, device)
        pairwise_distance_matrix = create_pairwise_distance_matrix(maxlen, device)

    
        dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_function,  num_workers=0)
        
        model = MiniTransformer(p, nheads, dk, dv, ncum, mask, pairwise_distance_matrix, distance_to_end_matrix,  device)

        model.apply(init_weights_recursive)
        model.to(device)

        # model = torch.compile(model)
        # Start the timer
        start_time = time.time()

        # Define optimizer
        # optimizer = optim.Adam(model.parameters(), lr= learning_rate, weight_decay=lambda_l2)
        optimizer = optim.Adam(model.parameters(), lr= learning_rate)
        
        print("Number of Parameters", transformerFunctions.count_parameters(model))
        
        run_path = transformerFunctions.train_mini_transformer(model, dataloader, optimizer, lambda_l2, EPOCHS, device)


        # # Enable profiling
        # with profiler.profile() as prof:

        #     model.eval() 
        #     # Forward pass
        #     output = model(train_dataset.data)
        #     # Backward pass (this will profile the backward pass as well)
        #     output.backward(torch.ones_like(output))

        # # Print profiling results
        # print(prof.key_averages().table(sort_by="cpu_time_total", row_limit=10))



        # End the timer
        end_time = time.time()

        # Calculate and print the execution time
        execution_time = end_time - start_time 
        print(f"Execution time: {execution_time:.6f} seconds")


        
        
        
        # Evaluate the model
        
        eval_dataloader = DataLoader(eval_dataset, batch_size=1, shuffle=True, collate_fn=collate_function, num_workers=0)
       
    
    
        dimave, bench1_loss, benchloss_predindex = calculate_bench1_loss(train_dataset, eval_dataset, predindex)
        regression_loss_predindex, regression_loss_total = calculate_regression_loss(train_dataset, eval_dataset, predindex)
        model_loss_predindex, model_loss_total = evaluate_mini_transformer(eval_dataloader, model, predindex)
        
        
        print("baseline average loss: ", bench1_loss)

        
        # Evaluate the model
        if data_str == "simulation":
            bench2loss, bench2loss_predindex = calculate_bench2_loss(train_dataset, eval_dataset, dimave)
            print("baseline informed loss: ", bench2loss)
            bench2_loss_list.append(bench2loss)
            bench2loss_predindex_list.append(bench2loss_predindex)
            
        else:
            bench_repeat, bench_repeat_predindex = calculate_repeat_loss(eval_dataset, predindex)    
            print("baseline repeat: ", bench_repeat)
            
            
            
        print("regression loss total: ", regression_loss_total)
        print("model loss total: ", model_loss_total.item(), "\n") 
        
        
        if data_str == "simulation":
            print("baseline informed loss predindex: ", bench2loss_predindex)
            bench2loss_predindex_list.append(bench2loss_predindex)
            
        print("baseline average loss predindex: ", benchloss_predindex)
        print("baseline repeat predindex: ", bench_repeat_predindex)    
        print("regression loss predindex: ", regression_loss_predindex)
        print("model loss predindex: ", model_loss_predindex.item()) 


        
        
        bench_repeat_loss_list.append(bench_repeat)
        regression_loss_total_list.append(regression_loss_total)
        model_loss_total_list.append(model_loss_total.item())
        benchloss_predindex_list.append(benchloss_predindex)
        bench_repeat_loss_predindex_list.append(bench_repeat_predindex)
        regression_loss_predindex_list.append(regression_loss_predindex)
        model_loss_predindex_list.append(model_loss_predindex.item())
        bench1_loss_list.append(bench1_loss)
        
        
        
# save the mean and std of these lists in text file in the format of mean ± std 
# os.chdir("./notebooks/results")




with open(f"./notebooks/{data_str}_results_n={n}_batch_size={batch_size}_p={p}_ncum={ncum}_nheads={nheads}_epochs={EPOCHS}.txt", "a") as f:
    # First line
    f.write(f"{data_str} results n = {n}\n")

    # Single-line writes with three-decimal formatting:
    f.write(f"baseline repeat: {statistics.mean(bench_repeat_loss_list):.3f} ± {statistics.stdev(bench_repeat_loss_list):.3f}\n")
    f.write(f"baseline average loss: {statistics.mean(bench1_loss_list):.3f} ± {statistics.stdev(bench1_loss_list):.3f}\n")
    if data_str == "simulation":
        f.write(f"baseline informed loss: {statistics.mean(bench2_loss_list):.3f} ± {statistics.stdev(bench2_loss_list):.3f}\n")
        
    f.write(f"regression loss total: {statistics.mean(regression_loss_total_list):.3f} ± {statistics.stdev(regression_loss_total_list):.3f}\n")
    f.write(f"model loss total: {statistics.mean(model_loss_total_list):.3f} ± {statistics.stdev(model_loss_total_list):.3f}\n\n")

    
    f.write(f"baseline repeat predindex: {statistics.mean(bench_repeat_loss_predindex_list):.3f} ± {statistics.stdev(bench_repeat_loss_list):.3f}\n")
    f.write(f"baseline average loss predindex: {statistics.mean(benchloss_predindex_list):.3f} ± {statistics.stdev(benchloss_predindex_list):.3f}\n")
    f.write(f"regression loss predindex: {statistics.mean(regression_loss_predindex_list):.3f} ± {statistics.stdev(regression_loss_predindex_list):.3f}\n")
    if data_str == "simulation":
        f.write(f"baseline informed loss predindex: {statistics.mean(bench2loss_predindex_list):.3f} ± {statistics.stdev(bench2loss_predindex_list):.3f}\n")
    f.write(f"model loss predindex: {statistics.mean(model_loss_predindex_list):.3f} ± {statistics.stdev(model_loss_predindex_list):.3f}\n")

    # Extra newlines at the end
    f.write("\n\n")
# Out:
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 256
# EPOCH 1:
# avg_loss: 18.17838
# EPOCH 2:
# avg_loss: 14.32891
# EPOCH 3:
# avg_loss: 13.93129
# EPOCH 4:
# avg_loss: 13.72926
# EPOCH 5:
# avg_loss: 13.60900
# EPOCH 6:
# avg_loss: 13.54083
# EPOCH 7:
# avg_loss: 13.49172
# EPOCH 8:
# avg_loss: 13.46576
# EPOCH 9:
# avg_loss: 13.43791
# EPOCH 10:
# avg_loss: 13.41408
# EPOCH 11:
# avg_loss: 13.40676
# EPOCH 12:
# avg_loss: 13.38990
# EPOCH 13:
# avg_loss: 13.38408
# EPOCH 14:
# avg_loss: 13.36642
# EPOCH 15:
# avg_loss: 13.33101
# EPOCH 16:
# avg_loss: 13.29219
# EPOCH 17:
# avg_loss: 13.25409
# EPOCH 18:
# avg_loss: 13.22782
# EPOCH 19:
# avg_loss: 13.19622
# EPOCH 20:
# avg_loss: 13.15926
# EPOCH 21:
# avg_loss: 13.13363
# EPOCH 22:
# avg_loss: 13.12438
# EPOCH 23:
# avg_loss: 13.10074
# EPOCH 24:
# avg_loss: 13.09034
# EPOCH 25:
# avg_loss: 13.07697
# EPOCH 26:
# avg_loss: 13.06224
# EPOCH 27:
# avg_loss: 13.04967
# EPOCH 28:
# avg_loss: 13.03235
# EPOCH 29:
# avg_loss: 13.02409
# EPOCH 30:
# avg_loss: 13.01146
# EPOCH 31:
# avg_loss: 12.99393
# EPOCH 32:
# avg_loss: 12.96898
# EPOCH 33:
# avg_loss: 12.94943
# EPOCH 34:
# avg_loss: 12.92156
# EPOCH 35:
# avg_loss: 12.89368
# EPOCH 36:
# avg_loss: 12.86870
# EPOCH 37:
# avg_loss: 12.85156
# EPOCH 38:
# avg_loss: 12.84317
# EPOCH 39:
# avg_loss: 12.83432
# EPOCH 40:
# avg_loss: 12.81780
# EPOCH 41:
# avg_loss: 12.81890
# EPOCH 42:
# avg_loss: 12.81279
# EPOCH 43:
# avg_loss: 12.80122
# EPOCH 44:
# avg_loss: 12.79154
# EPOCH 45:
# avg_loss: 12.77798
# EPOCH 46:
# avg_loss: 12.76801
# EPOCH 47:
# avg_loss: 12.75762
# EPOCH 48:
# avg_loss: 12.75584
# EPOCH 49:
# avg_loss: 12.74718
# EPOCH 50:
# avg_loss: 12.73375
# EPOCH 51:
# avg_loss: 12.72967
# EPOCH 52:
# avg_loss: 12.72558
# EPOCH 53:
# avg_loss: 12.71964
# EPOCH 54:
# avg_loss: 12.71936
# EPOCH 55:
# avg_loss: 12.71974
# EPOCH 56:
# avg_loss: 12.71533
# EPOCH 57:
# avg_loss: 12.70737
# EPOCH 58:
# avg_loss: 12.71129
# EPOCH 59:
# avg_loss: 12.70412
# EPOCH 60:
# avg_loss: 12.70263
# EPOCH 61:
# avg_loss: 12.70074
# EPOCH 62:
# avg_loss: 12.69599
# EPOCH 63:
# avg_loss: 12.68611
# EPOCH 64:
# avg_loss: 12.66642
# EPOCH 65:
# avg_loss: 12.62950
# EPOCH 66:
# avg_loss: 12.58727
# EPOCH 67:
# avg_loss: 12.56771
# EPOCH 68:
# avg_loss: 12.52954
# EPOCH 69:
# avg_loss: 12.49844
# EPOCH 70:
# avg_loss: 12.47607
# EPOCH 71:
# avg_loss: 12.45631
# EPOCH 72:
# avg_loss: 12.44024
# EPOCH 73:
# avg_loss: 12.43043
# EPOCH 74:
# avg_loss: 12.42782
# EPOCH 75:
# avg_loss: 12.41888
# EPOCH 76:
# avg_loss: 12.40288
# EPOCH 77:
# avg_loss: 12.40170
# EPOCH 78:
# avg_loss: 12.39660
# EPOCH 79:
# avg_loss: 12.38560
# EPOCH 80:
# avg_loss: 12.38237
# EPOCH 81:
# avg_loss: 12.37907
# EPOCH 82:
# avg_loss: 12.38019
# EPOCH 83:
# avg_loss: 12.36683
# EPOCH 84:
# avg_loss: 12.37489
# EPOCH 85:
# avg_loss: 12.36177
# EPOCH 86:
# avg_loss: 12.36750
# EPOCH 87:
# avg_loss: 12.36306
# EPOCH 88:
# avg_loss: 12.36272
# EPOCH 89:
# avg_loss: 12.36531
# EPOCH 90:
# avg_loss: 12.35825
# EPOCH 91:
# avg_loss: 12.35637
# EPOCH 92:
# avg_loss: 12.35783
# EPOCH 93:
# avg_loss: 12.36067
# EPOCH 94:
# avg_loss: 12.36324
# EPOCH 95:
# avg_loss: 12.35717
# EPOCH 96:
# avg_loss: 12.35895
# EPOCH 97:
# avg_loss: 12.35489
# EPOCH 98:
# avg_loss: 12.35471
# EPOCH 99:
# avg_loss: 12.36069
# EPOCH 100:
# avg_loss: 12.35626
# Execution time: 69.089370 seconds
# baseline average loss:  0.15859759196808393
# baseline repeat:  0.21477273148907858
# regression loss total:  0.14276478477855387
# model loss total:  0.14205266535282135
#
# baseline average loss predindex:  0.2244398214600303
# baseline repeat predindex:  0.2840909090909091
# regression loss predindex:  0.1904359268614326
# model loss predindex:  0.17908944189548492
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 256
# EPOCH 1:
# avg_loss: 18.42516
# EPOCH 2:
# avg_loss: 14.40660
# EPOCH 3:
# avg_loss: 13.99572
# EPOCH 4:
# avg_loss: 13.78886
# EPOCH 5:
# avg_loss: 13.66605
# EPOCH 6:
# avg_loss: 13.60441
# EPOCH 7:
# avg_loss: 13.55833
# EPOCH 8:
# avg_loss: 13.51671
# EPOCH 9:
# avg_loss: 13.49824
# EPOCH 10:
# avg_loss: 13.47909
# EPOCH 11:
# avg_loss: 13.46560
# EPOCH 12:
# avg_loss: 13.45949
# EPOCH 13:
# avg_loss: 13.45396
# EPOCH 14:
# avg_loss: 13.44318
# EPOCH 15:
# avg_loss: 13.43843
# EPOCH 16:
# avg_loss: 13.42518
# EPOCH 17:
# avg_loss: 13.41086
# EPOCH 18:
# avg_loss: 13.39953
# EPOCH 19:
# avg_loss: 13.37253
# EPOCH 20:
# avg_loss: 13.32746
# EPOCH 21:
# avg_loss: 13.25812
# EPOCH 22:
# avg_loss: 13.20183
# EPOCH 23:
# avg_loss: 13.16652
# EPOCH 24:
# avg_loss: 13.14398
# EPOCH 25:
# avg_loss: 13.13133
# EPOCH 26:
# avg_loss: 13.12498
# EPOCH 27:
# avg_loss: 13.12030
# EPOCH 28:
# avg_loss: 13.11691
# EPOCH 29:
# avg_loss: 13.10276
# EPOCH 30:
# avg_loss: 13.09907
# EPOCH 31:
# avg_loss: 13.08784
# EPOCH 32:
# avg_loss: 13.07906
# EPOCH 33:
# avg_loss: 13.07096
# EPOCH 34:
# avg_loss: 13.04537
# EPOCH 35:
# avg_loss: 13.02336
# EPOCH 36:
# avg_loss: 13.00485
# EPOCH 37:
# avg_loss: 12.97661
# EPOCH 38:
# avg_loss: 12.96126
# EPOCH 39:
# avg_loss: 12.95041
# EPOCH 40:
# avg_loss: 12.94006
# EPOCH 41:
# avg_loss: 12.92398
# EPOCH 42:
# avg_loss: 12.91900
# EPOCH 43:
# avg_loss: 12.91361
# EPOCH 44:
# avg_loss: 12.89922
# EPOCH 45:
# avg_loss: 12.89638
# EPOCH 46:
# avg_loss: 12.88557
# EPOCH 47:
# avg_loss: 12.87954
# EPOCH 48:
# avg_loss: 12.87067
# EPOCH 49:
# avg_loss: 12.87019
# EPOCH 50:
# avg_loss: 12.86466
# EPOCH 51:
# avg_loss: 12.85747
# EPOCH 52:
# avg_loss: 12.85941
# EPOCH 53:
# avg_loss: 12.84972
# EPOCH 54:
# avg_loss: 12.84609
# EPOCH 55:
# avg_loss: 12.84711
# EPOCH 56:
# avg_loss: 12.84096
# EPOCH 57:
# avg_loss: 12.84168
# EPOCH 58:
# avg_loss: 12.83590
# EPOCH 59:
# avg_loss: 12.83560
# EPOCH 60:
# avg_loss: 12.83549
# EPOCH 61:
# avg_loss: 12.83312
# EPOCH 62:
# avg_loss: 12.83072
# EPOCH 63:
# avg_loss: 12.82965
# EPOCH 64:
# avg_loss: 12.82355
# EPOCH 65:
# avg_loss: 12.82485
# EPOCH 66:
# avg_loss: 12.81954
# EPOCH 67:
# avg_loss: 12.82055
# EPOCH 68:
# avg_loss: 12.82151
# EPOCH 69:
# avg_loss: 12.82108
# EPOCH 70:
# avg_loss: 12.81545
# EPOCH 71:
# avg_loss: 12.81771
# EPOCH 72:
# avg_loss: 12.81490
# EPOCH 73:
# avg_loss: 12.81779
# EPOCH 74:
# avg_loss: 12.81358
# EPOCH 75:
# avg_loss: 12.80662
# EPOCH 76:
# avg_loss: 12.81730
# EPOCH 77:
# avg_loss: 12.81362
# EPOCH 78:
# avg_loss: 12.81296
# EPOCH 79:
# avg_loss: 12.80655
# EPOCH 80:
# avg_loss: 12.81103
# EPOCH 81:
# avg_loss: 12.79757
# EPOCH 82:
# avg_loss: 12.80651
# EPOCH 83:
# avg_loss: 12.80921
# EPOCH 84:
# avg_loss: 12.80747
# EPOCH 85:
# avg_loss: 12.81221
# EPOCH 86:
# avg_loss: 12.80707
# EPOCH 87:
# avg_loss: 12.80482
# EPOCH 88:
# avg_loss: 12.80667
# EPOCH 89:
# avg_loss: 12.81025
# EPOCH 90:
# avg_loss: 12.80304
# EPOCH 91:
# avg_loss: 12.80529
# EPOCH 92:
# avg_loss: 12.80200
# EPOCH 93:
# avg_loss: 12.80396
# EPOCH 94:
# avg_loss: 12.79960
# EPOCH 95:
# avg_loss: 12.80199
# EPOCH 96:
# avg_loss: 12.80153
# EPOCH 97:
# avg_loss: 12.79963
# EPOCH 98:
# avg_loss: 12.80308
# EPOCH 99:
# avg_loss: 12.80364
# EPOCH 100:
# avg_loss: 12.80054
# Execution time: 69.306709 seconds
# baseline average loss:  0.14526255001229318
# baseline repeat:  0.18068182205950672
# regression loss total:  0.121073489383054
# model loss total:  0.12619607150554657
#
# baseline average loss predindex:  0.19834864139556885
# baseline repeat predindex:  0.1590909090909091
# regression loss predindex:  0.1363007399193434
# model loss predindex:  0.15212424099445343
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 256
# EPOCH 1:
# avg_loss: 18.64853
# EPOCH 2:
# avg_loss: 14.50319
# EPOCH 3:
# avg_loss: 14.07939
# EPOCH 4:
# avg_loss: 13.87146
# EPOCH 5:
# avg_loss: 13.74829
# EPOCH 6:
# avg_loss: 13.67295
# EPOCH 7:
# avg_loss: 13.62548
# EPOCH 8:
# avg_loss: 13.59202
# EPOCH 9:
# avg_loss: 13.57045
# EPOCH 10:
# avg_loss: 13.55346
# EPOCH 11:
# avg_loss: 13.53410
# EPOCH 12:
# avg_loss: 13.52666
# EPOCH 13:
# avg_loss: 13.51555
# EPOCH 14:
# avg_loss: 13.50565
# EPOCH 15:
# avg_loss: 13.49034
# EPOCH 16:
# avg_loss: 13.46710
# EPOCH 17:
# avg_loss: 13.41736
# EPOCH 18:
# avg_loss: 13.33353
# EPOCH 19:
# avg_loss: 13.26944
# EPOCH 20:
# avg_loss: 13.22310
# EPOCH 21:
# avg_loss: 13.18520
# EPOCH 22:
# avg_loss: 13.16754
# EPOCH 23:
# avg_loss: 13.14453
# EPOCH 24:
# avg_loss: 13.13526
# EPOCH 25:
# avg_loss: 13.10853
# EPOCH 26:
# avg_loss: 13.09589
# EPOCH 27:
# avg_loss: 13.07540
# EPOCH 28:
# avg_loss: 13.06342
# EPOCH 29:
# avg_loss: 13.04450
# EPOCH 30:
# avg_loss: 13.03928
# EPOCH 31:
# avg_loss: 13.02392
# EPOCH 32:
# avg_loss: 13.02370
# EPOCH 33:
# avg_loss: 13.00822
# EPOCH 34:
# avg_loss: 13.00430
# EPOCH 35:
# avg_loss: 13.00178
# EPOCH 36:
# avg_loss: 12.99292
# EPOCH 37:
# avg_loss: 12.98655
# EPOCH 38:
# avg_loss: 12.97939
# EPOCH 39:
# avg_loss: 12.96966
# EPOCH 40:
# avg_loss: 12.96035
# EPOCH 41:
# avg_loss: 12.95568
# EPOCH 42:
# avg_loss: 12.94367
# EPOCH 43:
# avg_loss: 12.94120
# EPOCH 44:
# avg_loss: 12.92726
# EPOCH 45:
# avg_loss: 12.92375
# EPOCH 46:
# avg_loss: 12.90927
# EPOCH 47:
# avg_loss: 12.90758
# EPOCH 48:
# avg_loss: 12.90175
# EPOCH 49:
# avg_loss: 12.88494
# EPOCH 50:
# avg_loss: 12.88186
# EPOCH 51:
# avg_loss: 12.87413
# EPOCH 52:
# avg_loss: 12.86850
# EPOCH 53:
# avg_loss: 12.86117
# EPOCH 54:
# avg_loss: 12.85498
# EPOCH 55:
# avg_loss: 12.82877
# EPOCH 56:
# avg_loss: 12.78116
# EPOCH 57:
# avg_loss: 12.75219
# EPOCH 58:
# avg_loss: 12.70865
# EPOCH 59:
# avg_loss: 12.67406
# EPOCH 60:
# avg_loss: 12.63672
# EPOCH 61:
# avg_loss: 12.61261
# EPOCH 62:
# avg_loss: 12.58942
# EPOCH 63:
# avg_loss: 12.57986
# EPOCH 64:
# avg_loss: 12.56203
# EPOCH 65:
# avg_loss: 12.55284
# EPOCH 66:
# avg_loss: 12.54743
# EPOCH 67:
# avg_loss: 12.54292
# EPOCH 68:
# avg_loss: 12.53540
# EPOCH 69:
# avg_loss: 12.52189
# EPOCH 70:
# avg_loss: 12.51886
# EPOCH 71:
# avg_loss: 12.51582
# EPOCH 72:
# avg_loss: 12.51185
# EPOCH 73:
# avg_loss: 12.50840
# EPOCH 74:
# avg_loss: 12.50272
# EPOCH 75:
# avg_loss: 12.50311
# EPOCH 76:
# avg_loss: 12.49761
# EPOCH 77:
# avg_loss: 12.49715
# EPOCH 78:
# avg_loss: 12.49321
# EPOCH 79:
# avg_loss: 12.49034
# EPOCH 80:
# avg_loss: 12.49905
# EPOCH 81:
# avg_loss: 12.49295
# EPOCH 82:
# avg_loss: 12.49561
# EPOCH 83:
# avg_loss: 12.49608
# EPOCH 84:
# avg_loss: 12.48926
# EPOCH 85:
# avg_loss: 12.49216
# EPOCH 86:
# avg_loss: 12.48734
# EPOCH 87:
# avg_loss: 12.49095
# EPOCH 88:
# avg_loss: 12.49252
# EPOCH 89:
# avg_loss: 12.48183
# EPOCH 90:
# avg_loss: 12.48992
# EPOCH 91:
# avg_loss: 12.48067
# EPOCH 92:
# avg_loss: 12.49454
# EPOCH 93:
# avg_loss: 12.48403
# EPOCH 94:
# avg_loss: 12.48647
# EPOCH 95:
# avg_loss: 12.49116
# EPOCH 96:
# avg_loss: 12.48966
# EPOCH 97:
# avg_loss: 12.49326
# EPOCH 98:
# avg_loss: 12.48655
# EPOCH 99:
# avg_loss: 12.49041
# EPOCH 100:
# avg_loss: 12.49525
# Execution time: 69.932367 seconds
# baseline average loss:  0.1499276178550314
# baseline repeat:  0.23068182297389617
# regression loss total:  0.1358609797984465
# model loss total:  0.13233605027198792
#
# baseline average loss predindex:  0.19835196841846814
# baseline repeat predindex:  0.3522727272727273
# regression loss predindex:  0.20026124068018383
# model loss predindex:  0.18559609353542328
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 256
# EPOCH 1:
# avg_loss: 18.06742
# EPOCH 2:
# avg_loss: 14.28455
# EPOCH 3:
# avg_loss: 13.88213
# EPOCH 4:
# avg_loss: 13.67468
# EPOCH 5:
# avg_loss: 13.56526
# EPOCH 6:
# avg_loss: 13.49767
# EPOCH 7:
# avg_loss: 13.45503
# EPOCH 8:
# avg_loss: 13.42067
# EPOCH 9:
# avg_loss: 13.40006
# EPOCH 10:
# avg_loss: 13.37938
# EPOCH 11:
# avg_loss: 13.37379
# EPOCH 12:
# avg_loss: 13.36428
# EPOCH 13:
# avg_loss: 13.35828
# EPOCH 14:
# avg_loss: 13.34339
# EPOCH 15:
# avg_loss: 13.34023
# EPOCH 16:
# avg_loss: 13.31993
# EPOCH 17:
# avg_loss: 13.30142
# EPOCH 18:
# avg_loss: 13.26150
# EPOCH 19:
# avg_loss: 13.20150
# EPOCH 20:
# avg_loss: 13.14953
# EPOCH 21:
# avg_loss: 13.10112
# EPOCH 22:
# avg_loss: 13.05916
# EPOCH 23:
# avg_loss: 13.01927
# EPOCH 24:
# avg_loss: 12.98019
# EPOCH 25:
# avg_loss: 12.93505
# EPOCH 26:
# avg_loss: 12.89359
# EPOCH 27:
# avg_loss: 12.86408
# EPOCH 28:
# avg_loss: 12.84818
# EPOCH 29:
# avg_loss: 12.83652
# EPOCH 30:
# avg_loss: 12.81645
# EPOCH 31:
# avg_loss: 12.81131
# EPOCH 32:
# avg_loss: 12.79894
# EPOCH 33:
# avg_loss: 12.77726
# EPOCH 34:
# avg_loss: 12.76386
# EPOCH 35:
# avg_loss: 12.74504
# EPOCH 36:
# avg_loss: 12.73790
# EPOCH 37:
# avg_loss: 12.71706
# EPOCH 38:
# avg_loss: 12.71216
# EPOCH 39:
# avg_loss: 12.69379
# EPOCH 40:
# avg_loss: 12.69074
# EPOCH 41:
# avg_loss: 12.68599
# EPOCH 42:
# avg_loss: 12.68043
# EPOCH 43:
# avg_loss: 12.67631
# EPOCH 44:
# avg_loss: 12.66939
# EPOCH 45:
# avg_loss: 12.66736
# EPOCH 46:
# avg_loss: 12.66522
# EPOCH 47:
# avg_loss: 12.65728
# EPOCH 48:
# avg_loss: 12.64695
# EPOCH 49:
# avg_loss: 12.61960
# EPOCH 50:
# avg_loss: 12.57863
# EPOCH 51:
# avg_loss: 12.54753
# EPOCH 52:
# avg_loss: 12.51395
# EPOCH 53:
# avg_loss: 12.48628
# EPOCH 54:
# avg_loss: 12.45499
# EPOCH 55:
# avg_loss: 12.44082
# EPOCH 56:
# avg_loss: 12.42211
# EPOCH 57:
# avg_loss: 12.41290
# EPOCH 58:
# avg_loss: 12.39959
# EPOCH 59:
# avg_loss: 12.39259
# EPOCH 60:
# avg_loss: 12.38459
# EPOCH 61:
# avg_loss: 12.38313
# EPOCH 62:
# avg_loss: 12.37174
# EPOCH 63:
# avg_loss: 12.36729
# EPOCH 64:
# avg_loss: 12.36190
# EPOCH 65:
# avg_loss: 12.34958
# EPOCH 66:
# avg_loss: 12.35465
# EPOCH 67:
# avg_loss: 12.34900
# EPOCH 68:
# avg_loss: 12.34591
# EPOCH 69:
# avg_loss: 12.34273
# EPOCH 70:
# avg_loss: 12.34656
# EPOCH 71:
# avg_loss: 12.34766
# EPOCH 72:
# avg_loss: 12.34103
# EPOCH 73:
# avg_loss: 12.33950
# EPOCH 74:
# avg_loss: 12.34313
# EPOCH 75:
# avg_loss: 12.34264
# EPOCH 76:
# avg_loss: 12.34165
# EPOCH 77:
# avg_loss: 12.34060
# EPOCH 78:
# avg_loss: 12.34019
# EPOCH 79:
# avg_loss: 12.34116
# EPOCH 80:
# avg_loss: 12.34048
# EPOCH 81:
# avg_loss: 12.34406
# EPOCH 82:
# avg_loss: 12.33761
# EPOCH 83:
# avg_loss: 12.33480
# EPOCH 84:
# avg_loss: 12.33896
# EPOCH 85:
# avg_loss: 12.33126
# EPOCH 86:
# avg_loss: 12.33720
# EPOCH 87:
# avg_loss: 12.33692
# EPOCH 88:
# avg_loss: 12.34087
# EPOCH 89:
# avg_loss: 12.33879
# EPOCH 90:
# avg_loss: 12.34428
# EPOCH 91:
# avg_loss: 12.33439
# EPOCH 92:
# avg_loss: 12.33651
# EPOCH 93:
# avg_loss: 12.33156
# EPOCH 94:
# avg_loss: 12.33662
# EPOCH 95:
# avg_loss: 12.33602
# EPOCH 96:
# avg_loss: 12.33553
# EPOCH 97:
# avg_loss: 12.33055
# EPOCH 98:
# avg_loss: 12.33164
# EPOCH 99:
# avg_loss: 12.33515
# EPOCH 100:
# avg_loss: 12.33410
# Execution time: 68.881848 seconds
# baseline average loss:  0.1582697843286124
# baseline repeat:  0.23863636829297652
# regression loss total:  0.14877931341633457
# model loss total:  0.14115005731582642
#
# baseline average loss predindex:  0.22378400882536714
# baseline repeat predindex:  0.32954545454545453
# regression loss predindex:  0.21317685548804696
# model loss predindex:  0.2059459090232849
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 256
# EPOCH 1:
# avg_loss: 18.40164
# EPOCH 2:
# avg_loss: 14.34918
# EPOCH 3:
# avg_loss: 13.93298
# EPOCH 4:
# avg_loss: 13.71771
# EPOCH 5:
# avg_loss: 13.59191
# EPOCH 6:
# avg_loss: 13.52433
# EPOCH 7:
# avg_loss: 13.47829
# EPOCH 8:
# avg_loss: 13.43551
# EPOCH 9:
# avg_loss: 13.41465
# EPOCH 10:
# avg_loss: 13.40275
# EPOCH 11:
# avg_loss: 13.38308
# EPOCH 12:
# avg_loss: 13.36885
# EPOCH 13:
# avg_loss: 13.36254
# EPOCH 14:
# avg_loss: 13.34533
# EPOCH 15:
# avg_loss: 13.31894
# EPOCH 16:
# avg_loss: 13.25963
# EPOCH 17:
# avg_loss: 13.18039
# EPOCH 18:
# avg_loss: 13.11375
# EPOCH 19:
# avg_loss: 13.06928
# EPOCH 20:
# avg_loss: 13.04248
# EPOCH 21:
# avg_loss: 13.02962
# EPOCH 22:
# avg_loss: 13.01496
# EPOCH 23:
# avg_loss: 13.00278
# EPOCH 24:
# avg_loss: 12.99819
# EPOCH 25:
# avg_loss: 12.99189
# EPOCH 26:
# avg_loss: 12.97908
# EPOCH 27:
# avg_loss: 12.96676
# EPOCH 28:
# avg_loss: 12.95347
# EPOCH 29:
# avg_loss: 12.93644
# EPOCH 30:
# avg_loss: 12.92689
# EPOCH 31:
# avg_loss: 12.90434
# EPOCH 32:
# avg_loss: 12.88273
# EPOCH 33:
# avg_loss: 12.87061
# EPOCH 34:
# avg_loss: 12.85857
# EPOCH 35:
# avg_loss: 12.84123
# EPOCH 36:
# avg_loss: 12.82280
# EPOCH 37:
# avg_loss: 12.79973
# EPOCH 38:
# avg_loss: 12.77835
# EPOCH 39:
# avg_loss: 12.75392
# EPOCH 40:
# avg_loss: 12.74526
# EPOCH 41:
# avg_loss: 12.72855
# EPOCH 42:
# avg_loss: 12.71622
# EPOCH 43:
# avg_loss: 12.71873
# EPOCH 44:
# avg_loss: 12.71044
# EPOCH 45:
# avg_loss: 12.71076
# EPOCH 46:
# avg_loss: 12.70594
# EPOCH 47:
# avg_loss: 12.70177
# EPOCH 48:
# avg_loss: 12.69753
# EPOCH 49:
# avg_loss: 12.69153
# EPOCH 50:
# avg_loss: 12.69231
# EPOCH 51:
# avg_loss: 12.69174
# EPOCH 52:
# avg_loss: 12.68101
# EPOCH 53:
# avg_loss: 12.66570
# EPOCH 54:
# avg_loss: 12.63755
# EPOCH 55:
# avg_loss: 12.60176
# EPOCH 56:
# avg_loss: 12.56085
# EPOCH 57:
# avg_loss: 12.53357
# EPOCH 58:
# avg_loss: 12.49857
# EPOCH 59:
# avg_loss: 12.47203
# EPOCH 60:
# avg_loss: 12.45142
# EPOCH 61:
# avg_loss: 12.43764
# EPOCH 62:
# avg_loss: 12.42318
# EPOCH 63:
# avg_loss: 12.41429
# EPOCH 64:
# avg_loss: 12.40912
# EPOCH 65:
# avg_loss: 12.39714
# EPOCH 66:
# avg_loss: 12.39707
# EPOCH 67:
# avg_loss: 12.39281
# EPOCH 68:
# avg_loss: 12.38297
# EPOCH 69:
# avg_loss: 12.38404
# EPOCH 70:
# avg_loss: 12.37744
# EPOCH 71:
# avg_loss: 12.37083
# EPOCH 72:
# avg_loss: 12.36373
# EPOCH 73:
# avg_loss: 12.36704
# EPOCH 74:
# avg_loss: 12.36275
# EPOCH 75:
# avg_loss: 12.36150
# EPOCH 76:
# avg_loss: 12.36029
# EPOCH 77:
# avg_loss: 12.35646
# EPOCH 78:
# avg_loss: 12.35427
# EPOCH 79:
# avg_loss: 12.36006
# EPOCH 80:
# avg_loss: 12.35314
# EPOCH 81:
# avg_loss: 12.35634
# EPOCH 82:
# avg_loss: 12.35012
# EPOCH 83:
# avg_loss: 12.35868
# EPOCH 84:
# avg_loss: 12.35718
# EPOCH 85:
# avg_loss: 12.35098
# EPOCH 86:
# avg_loss: 12.35009
# EPOCH 87:
# avg_loss: 12.34997
# EPOCH 88:
# avg_loss: 12.35241
# EPOCH 89:
# avg_loss: 12.35734
# EPOCH 90:
# avg_loss: 12.35234
# EPOCH 91:
# avg_loss: 12.35137
# EPOCH 92:
# avg_loss: 12.35165
# EPOCH 93:
# avg_loss: 12.35254
# EPOCH 94:
# avg_loss: 12.34972
# EPOCH 95:
# avg_loss: 12.35615
# EPOCH 96:
# avg_loss: 12.34934
# EPOCH 97:
# avg_loss: 12.35482
# EPOCH 98:
# avg_loss: 12.35155
# EPOCH 99:
# avg_loss: 12.34867
# EPOCH 100:
# avg_loss: 12.34992
# Execution time: 71.893483 seconds
# baseline average loss:  0.1490945308469236
# baseline repeat:  0.18295454962009733
# regression loss total:  0.1261951253998941
# model loss total:  0.1322031468153
#
# baseline average loss predindex:  0.19321499646387316
# baseline repeat predindex:  0.32954545454545453
# regression loss predindex:  0.18515294761453258
# model loss predindex:  0.18128658831119537
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 256
# EPOCH 1:
# avg_loss: 18.61676
# EPOCH 2:
# avg_loss: 14.51385
# EPOCH 3:
# avg_loss: 14.11043
# EPOCH 4:
# avg_loss: 13.90287
# EPOCH 5:
# avg_loss: 13.78311
# EPOCH 6:
# avg_loss: 13.71220
# EPOCH 7:
# avg_loss: 13.66022
# EPOCH 8:
# avg_loss: 13.64213
# EPOCH 9:
# avg_loss: 13.61024
# EPOCH 10:
# avg_loss: 13.59076
# EPOCH 11:
# avg_loss: 13.57390
# EPOCH 12:
# avg_loss: 13.56596
# EPOCH 13:
# avg_loss: 13.55323
# EPOCH 14:
# avg_loss: 13.54225
# EPOCH 15:
# avg_loss: 13.52384
# EPOCH 16:
# avg_loss: 13.48881
# EPOCH 17:
# avg_loss: 13.43550
# EPOCH 18:
# avg_loss: 13.35831
# EPOCH 19:
# avg_loss: 13.29870
# EPOCH 20:
# avg_loss: 13.25608
# EPOCH 21:
# avg_loss: 13.22989
# EPOCH 22:
# avg_loss: 13.21087
# EPOCH 23:
# avg_loss: 13.19928
# EPOCH 24:
# avg_loss: 13.18633
# EPOCH 25:
# avg_loss: 13.17182
# EPOCH 26:
# avg_loss: 13.15907
# EPOCH 27:
# avg_loss: 13.13472
# EPOCH 28:
# avg_loss: 13.10209
# EPOCH 29:
# avg_loss: 13.06435
# EPOCH 30:
# avg_loss: 13.04226
# EPOCH 31:
# avg_loss: 13.03318
# EPOCH 32:
# avg_loss: 13.02074
# EPOCH 33:
# avg_loss: 13.01402
# EPOCH 34:
# avg_loss: 13.00724
# EPOCH 35:
# avg_loss: 13.00668
# EPOCH 36:
# avg_loss: 13.00478
# EPOCH 37:
# avg_loss: 12.99758
# EPOCH 38:
# avg_loss: 13.00076
# EPOCH 39:
# avg_loss: 12.99445
# EPOCH 40:
# avg_loss: 12.98382
# EPOCH 41:
# avg_loss: 12.98712
# EPOCH 42:
# avg_loss: 12.98527
# EPOCH 43:
# avg_loss: 12.97799
# EPOCH 44:
# avg_loss: 12.97459
# EPOCH 45:
# avg_loss: 12.97296
# EPOCH 46:
# avg_loss: 12.96723
# EPOCH 47:
# avg_loss: 12.96044
# EPOCH 48:
# avg_loss: 12.95108
# EPOCH 49:
# avg_loss: 12.94217
# EPOCH 50:
# avg_loss: 12.93756
# EPOCH 51:
# avg_loss: 12.93416
# EPOCH 52:
# avg_loss: 12.93357
# EPOCH 53:
# avg_loss: 12.91653
# EPOCH 54:
# avg_loss: 12.91303
# EPOCH 55:
# avg_loss: 12.90152
# EPOCH 56:
# avg_loss: 12.90511
# EPOCH 57:
# avg_loss: 12.90056
# EPOCH 58:
# avg_loss: 12.89833
# EPOCH 59:
# avg_loss: 12.88887
# EPOCH 60:
# avg_loss: 12.89048
# EPOCH 61:
# avg_loss: 12.88333
# EPOCH 62:
# avg_loss: 12.88292
# EPOCH 63:
# avg_loss: 12.88340
# EPOCH 64:
# avg_loss: 12.88186
# EPOCH 65:
# avg_loss: 12.87673
# EPOCH 66:
# avg_loss: 12.87676
# EPOCH 67:
# avg_loss: 12.87323
# EPOCH 68:
# avg_loss: 12.87139
# EPOCH 69:
# avg_loss: 12.87033
# EPOCH 70:
# avg_loss: 12.86310
# EPOCH 71:
# avg_loss: 12.86170
# EPOCH 72:
# avg_loss: 12.86106
# EPOCH 73:
# avg_loss: 12.86019
# EPOCH 74:
# avg_loss: 12.86412
# EPOCH 75:
# avg_loss: 12.85900
# EPOCH 76:
# avg_loss: 12.85670
# EPOCH 77:
# avg_loss: 12.85999
# EPOCH 78:
# avg_loss: 12.85768
# EPOCH 79:
# avg_loss: 12.85793
# EPOCH 80:
# avg_loss: 12.85610
# EPOCH 81:
# avg_loss: 12.85440
# EPOCH 82:
# avg_loss: 12.85245
# EPOCH 83:
# avg_loss: 12.85385
# EPOCH 84:
# avg_loss: 12.85057
# EPOCH 85:
# avg_loss: 12.85161
# EPOCH 86:
# avg_loss: 12.85156
# EPOCH 87:
# avg_loss: 12.85603
# EPOCH 88:
# avg_loss: 12.85135
# EPOCH 89:
# avg_loss: 12.84779
# EPOCH 90:
# avg_loss: 12.84785
# EPOCH 91:
# avg_loss: 12.84947
# EPOCH 92:
# avg_loss: 12.84716
# EPOCH 93:
# avg_loss: 12.84960
# EPOCH 94:
# avg_loss: 12.84694
# EPOCH 95:
# avg_loss: 12.83913
# EPOCH 96:
# avg_loss: 12.84305
# EPOCH 97:
# avg_loss: 12.84586
# EPOCH 98:
# avg_loss: 12.84689
# EPOCH 99:
# avg_loss: 12.84540
# EPOCH 100:
# avg_loss: 12.84664
# Execution time: 64.990109 seconds
# baseline average loss:  0.14966008625924587
# baseline repeat:  0.2261363681913777
# regression loss total:  0.137947379549421
# model loss total:  0.13940195739269257
#
# baseline average loss predindex:  0.2034634706479582
# baseline repeat predindex:  0.26136363636363635
# regression loss predindex:  0.17850801415634893
# model loss predindex:  0.1746097356081009
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 256
# EPOCH 1:
# avg_loss: 18.55995
# EPOCH 2:
# avg_loss: 14.43744
# EPOCH 3:
# avg_loss: 14.04912
# EPOCH 4:
# avg_loss: 13.84809
# EPOCH 5:
# avg_loss: 13.72560
# EPOCH 6:
# avg_loss: 13.65212
# EPOCH 7:
# avg_loss: 13.60412
# EPOCH 8:
# avg_loss: 13.56860
# EPOCH 9:
# avg_loss: 13.55222
# EPOCH 10:
# avg_loss: 13.52935
# EPOCH 11:
# avg_loss: 13.51309
# EPOCH 12:
# avg_loss: 13.50950
# EPOCH 13:
# avg_loss: 13.50084
# EPOCH 14:
# avg_loss: 13.48758
# EPOCH 15:
# avg_loss: 13.47778
# EPOCH 16:
# avg_loss: 13.45804
# EPOCH 17:
# avg_loss: 13.43326
# EPOCH 18:
# avg_loss: 13.37576
# EPOCH 19:
# avg_loss: 13.29381
# EPOCH 20:
# avg_loss: 13.22293
# EPOCH 21:
# avg_loss: 13.18194
# EPOCH 22:
# avg_loss: 13.16330
# EPOCH 23:
# avg_loss: 13.15737
# EPOCH 24:
# avg_loss: 13.13908
# EPOCH 25:
# avg_loss: 13.12863
# EPOCH 26:
# avg_loss: 13.11515
# EPOCH 27:
# avg_loss: 13.10290
# EPOCH 28:
# avg_loss: 13.08604
# EPOCH 29:
# avg_loss: 13.06488
# EPOCH 30:
# avg_loss: 13.03417
# EPOCH 31:
# avg_loss: 13.01969
# EPOCH 32:
# avg_loss: 12.99819
# EPOCH 33:
# avg_loss: 12.98926
# EPOCH 34:
# avg_loss: 12.97461
# EPOCH 35:
# avg_loss: 12.96372
# EPOCH 36:
# avg_loss: 12.95036
# EPOCH 37:
# avg_loss: 12.93644
# EPOCH 38:
# avg_loss: 12.92421
# EPOCH 39:
# avg_loss: 12.89930
# EPOCH 40:
# avg_loss: 12.87455
# EPOCH 41:
# avg_loss: 12.85705
# EPOCH 42:
# avg_loss: 12.84405
# EPOCH 43:
# avg_loss: 12.82456
# EPOCH 44:
# avg_loss: 12.81633
# EPOCH 45:
# avg_loss: 12.81385
# EPOCH 46:
# avg_loss: 12.79813
# EPOCH 47:
# avg_loss: 12.78515
# EPOCH 48:
# avg_loss: 12.75586
# EPOCH 49:
# avg_loss: 12.70945
# EPOCH 50:
# avg_loss: 12.67360
# EPOCH 51:
# avg_loss: 12.64214
# EPOCH 52:
# avg_loss: 12.59924
# EPOCH 53:
# avg_loss: 12.57349
# EPOCH 54:
# avg_loss: 12.55372
# EPOCH 55:
# avg_loss: 12.54030
# EPOCH 56:
# avg_loss: 12.52947
# EPOCH 57:
# avg_loss: 12.51503
# EPOCH 58:
# avg_loss: 12.50698
# EPOCH 59:
# avg_loss: 12.50184
# EPOCH 60:
# avg_loss: 12.49101
# EPOCH 61:
# avg_loss: 12.48846
# EPOCH 62:
# avg_loss: 12.47816
# EPOCH 63:
# avg_loss: 12.47568
# EPOCH 64:
# avg_loss: 12.46892
# EPOCH 65:
# avg_loss: 12.46371
# EPOCH 66:
# avg_loss: 12.46259
# EPOCH 67:
# avg_loss: 12.45994
# EPOCH 68:
# avg_loss: 12.45902
# EPOCH 69:
# avg_loss: 12.45498
# EPOCH 70:
# avg_loss: 12.45563
# EPOCH 71:
# avg_loss: 12.44868
# EPOCH 72:
# avg_loss: 12.44954
# EPOCH 73:
# avg_loss: 12.44639
# EPOCH 74:
# avg_loss: 12.45294
# EPOCH 75:
# avg_loss: 12.44799
# EPOCH 76:
# avg_loss: 12.44561
# EPOCH 77:
# avg_loss: 12.44922
# EPOCH 78:
# avg_loss: 12.44809
# EPOCH 79:
# avg_loss: 12.44741
# EPOCH 80:
# avg_loss: 12.44909
# EPOCH 81:
# avg_loss: 12.44696
# EPOCH 82:
# avg_loss: 12.44628
# EPOCH 83:
# avg_loss: 12.44627
# EPOCH 84:
# avg_loss: 12.44680
# EPOCH 85:
# avg_loss: 12.44576
# EPOCH 86:
# avg_loss: 12.44556
# EPOCH 87:
# avg_loss: 12.44912
# EPOCH 88:
# avg_loss: 12.44608
# EPOCH 89:
# avg_loss: 12.45282
# EPOCH 90:
# avg_loss: 12.44471
# EPOCH 91:
# avg_loss: 12.45414
# EPOCH 92:
# avg_loss: 12.44107
# EPOCH 93:
# avg_loss: 12.44776
# EPOCH 94:
# avg_loss: 12.45053
# EPOCH 95:
# avg_loss: 12.44700
# EPOCH 96:
# avg_loss: 12.44797
# EPOCH 97:
# avg_loss: 12.44211
# EPOCH 98:
# avg_loss: 12.44920
# EPOCH 99:
# avg_loss: 12.44649
# EPOCH 100:
# avg_loss: 12.44615
# Execution time: 63.593941 seconds
# baseline average loss:  0.14734210454943505
# baseline repeat:  0.22500000419941815
# regression loss total:  0.13874017527501298
# model loss total:  0.1336541324853897
#
# baseline average loss predindex:  0.2443298101425171
# baseline repeat predindex:  0.2727272727272727
# regression loss predindex:  0.20511598438644646
# model loss predindex:  0.21729378402233124
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 256
# EPOCH 1:
# avg_loss: 18.62576
# EPOCH 2:
# avg_loss: 14.54291
# EPOCH 3:
# avg_loss: 14.11124
# EPOCH 4:
# avg_loss: 13.90532
# EPOCH 5:
# avg_loss: 13.79007
# EPOCH 6:
# avg_loss: 13.71185
# EPOCH 7:
# avg_loss: 13.66920
# EPOCH 8:
# avg_loss: 13.63067
# EPOCH 9:
# avg_loss: 13.60742
# EPOCH 10:
# avg_loss: 13.59573
# EPOCH 11:
# avg_loss: 13.58223
# EPOCH 12:
# avg_loss: 13.57002
# EPOCH 13:
# avg_loss: 13.56820
# EPOCH 14:
# avg_loss: 13.55207
# EPOCH 15:
# avg_loss: 13.54291
# EPOCH 16:
# avg_loss: 13.52382
# EPOCH 17:
# avg_loss: 13.49574
# EPOCH 18:
# avg_loss: 13.44792
# EPOCH 19:
# avg_loss: 13.36570
# EPOCH 20:
# avg_loss: 13.30263
# EPOCH 21:
# avg_loss: 13.24647
# EPOCH 22:
# avg_loss: 13.22023
# EPOCH 23:
# avg_loss: 13.19664
# EPOCH 24:
# avg_loss: 13.16499
# EPOCH 25:
# avg_loss: 13.12407
# EPOCH 26:
# avg_loss: 13.06690
# EPOCH 27:
# avg_loss: 13.03852
# EPOCH 28:
# avg_loss: 13.02939
# EPOCH 29:
# avg_loss: 13.02640
# EPOCH 30:
# avg_loss: 13.01274
# EPOCH 31:
# avg_loss: 13.00412
# EPOCH 32:
# avg_loss: 12.99431
# EPOCH 33:
# avg_loss: 12.99430
# EPOCH 34:
# avg_loss: 12.98861
# EPOCH 35:
# avg_loss: 12.98074
# EPOCH 36:
# avg_loss: 12.98259
# EPOCH 37:
# avg_loss: 12.97374
# EPOCH 38:
# avg_loss: 12.96809
# EPOCH 39:
# avg_loss: 12.95757
# EPOCH 40:
# avg_loss: 12.96007
# EPOCH 41:
# avg_loss: 12.94674
# EPOCH 42:
# avg_loss: 12.94041
# EPOCH 43:
# avg_loss: 12.93055
# EPOCH 44:
# avg_loss: 12.92131
# EPOCH 45:
# avg_loss: 12.90745
# EPOCH 46:
# avg_loss: 12.90004
# EPOCH 47:
# avg_loss: 12.88722
# EPOCH 48:
# avg_loss: 12.88137
# EPOCH 49:
# avg_loss: 12.86554
# EPOCH 50:
# avg_loss: 12.86810
# EPOCH 51:
# avg_loss: 12.85044
# EPOCH 52:
# avg_loss: 12.83008
# EPOCH 53:
# avg_loss: 12.79288
# EPOCH 54:
# avg_loss: 12.74836
# EPOCH 55:
# avg_loss: 12.71775
# EPOCH 56:
# avg_loss: 12.68690
# EPOCH 57:
# avg_loss: 12.64771
# EPOCH 58:
# avg_loss: 12.62478
# EPOCH 59:
# avg_loss: 12.60650
# EPOCH 60:
# avg_loss: 12.58531
# EPOCH 61:
# avg_loss: 12.57758
# EPOCH 62:
# avg_loss: 12.56641
# EPOCH 63:
# avg_loss: 12.55980
# EPOCH 64:
# avg_loss: 12.55116
# EPOCH 65:
# avg_loss: 12.54150
# EPOCH 66:
# avg_loss: 12.53932
# EPOCH 67:
# avg_loss: 12.53828
# EPOCH 68:
# avg_loss: 12.52774
# EPOCH 69:
# avg_loss: 12.52890
# EPOCH 70:
# avg_loss: 12.52261
# EPOCH 71:
# avg_loss: 12.52028
# EPOCH 72:
# avg_loss: 12.51853
# EPOCH 73:
# avg_loss: 12.51817
# EPOCH 74:
# avg_loss: 12.51421
# EPOCH 75:
# avg_loss: 12.51397
# EPOCH 76:
# avg_loss: 12.51133
# EPOCH 77:
# avg_loss: 12.51173
# EPOCH 78:
# avg_loss: 12.51577
# EPOCH 79:
# avg_loss: 12.50990
# EPOCH 80:
# avg_loss: 12.51023
# EPOCH 81:
# avg_loss: 12.50965
# EPOCH 82:
# avg_loss: 12.50825
# EPOCH 83:
# avg_loss: 12.50777
# EPOCH 84:
# avg_loss: 12.51420
# EPOCH 85:
# avg_loss: 12.50896
# EPOCH 86:
# avg_loss: 12.50795
# EPOCH 87:
# avg_loss: 12.51267
# EPOCH 88:
# avg_loss: 12.51058
# EPOCH 89:
# avg_loss: 12.51271
# EPOCH 90:
# avg_loss: 12.51039
# EPOCH 91:
# avg_loss: 12.50853
# EPOCH 92:
# avg_loss: 12.51379
# EPOCH 93:
# avg_loss: 12.50697
# EPOCH 94:
# avg_loss: 12.51239
# EPOCH 95:
# avg_loss: 12.50360
# EPOCH 96:
# avg_loss: 12.50300
# EPOCH 97:
# avg_loss: 12.50470
# EPOCH 98:
# avg_loss: 12.50749
# EPOCH 99:
# avg_loss: 12.51143
# EPOCH 100:
# avg_loss: 12.51077
# Execution time: 61.642558 seconds
# baseline average loss:  0.14695440884679556
# baseline repeat:  0.2125000050291419
# regression loss total:  0.13619163716746993
# model loss total:  0.13315171003341675
#
# baseline average loss predindex:  0.19835067337209528
# baseline repeat predindex:  0.32954545454545453
# regression loss predindex:  0.19736180993940725
# model loss predindex:  0.1818724125623703
# Train size:  791
#
# Val size:  87
#
# Number of Parameters 256
# EPOCH 1:
# avg_loss: 18.46639
# EPOCH 2:
# avg_loss: 14.38809
# EPOCH 3:
# avg_loss: 13.95421
# EPOCH 4:
# avg_loss: 13.74579
# EPOCH 5:
# avg_loss: 13.63233
# EPOCH 6:
# avg_loss: 13.56656
# EPOCH 7:
# avg_loss: 13.51579
# EPOCH 8:
# avg_loss: 13.48665
# EPOCH 9:
# avg_loss: 13.46633
# EPOCH 10:
# avg_loss: 13.45019
# EPOCH 11:
# avg_loss: 13.43048
# EPOCH 12:
# avg_loss: 13.42305
# EPOCH 13:
# avg_loss: 13.41389
# EPOCH 14:
# avg_loss: 13.40708
# EPOCH 15:
# avg_loss: 13.39444
# EPOCH 16:
# avg_loss: 13.38078
# EPOCH 17:
# avg_loss: 13.36930
# EPOCH 18:
# avg_loss: 13.34071
# EPOCH 19:
# avg_loss: 13.29300
# EPOCH 20:
# avg_loss: 13.25067
# EPOCH 21:
# avg_loss: 13.19937
# EPOCH 22:
# avg_loss: 13.15133
# EPOCH 23:
# avg_loss: 13.11295
# EPOCH 24:
# avg_loss: 13.07414
# EPOCH 25:
# avg_loss: 13.02698
# EPOCH 26:
# avg_loss: 12.97816
# EPOCH 27:
# avg_loss: 12.93443
# EPOCH 28:
# avg_loss: 12.90519
# EPOCH 29:
# avg_loss: 12.88474
# EPOCH 30:
# avg_loss: 12.87926
# EPOCH 31:
# avg_loss: 12.86986
# EPOCH 32:
# avg_loss: 12.85583
# EPOCH 33:
# avg_loss: 12.85351
# EPOCH 34:
# avg_loss: 12.84091
# EPOCH 35:
# avg_loss: 12.82999
# EPOCH 36:
# avg_loss: 12.81780
# EPOCH 37:
# avg_loss: 12.81494
# EPOCH 38:
# avg_loss: 12.80524
# EPOCH 39:
# avg_loss: 12.80161
# EPOCH 40:
# avg_loss: 12.78675
# EPOCH 41:
# avg_loss: 12.77698
# EPOCH 42:
# avg_loss: 12.77665
# EPOCH 43:
# avg_loss: 12.76733
# EPOCH 44:
# avg_loss: 12.75504
# EPOCH 45:
# avg_loss: 12.74849
# EPOCH 46:
# avg_loss: 12.74011
# EPOCH 47:
# avg_loss: 12.72846
# EPOCH 48:
# avg_loss: 12.71746
# EPOCH 49:
# avg_loss: 12.70075
# EPOCH 50:
# avg_loss: 12.66698
# EPOCH 51:
# avg_loss: 12.63213
# EPOCH 52:
# avg_loss: 12.59660
# EPOCH 53:
# avg_loss: 12.55399
# EPOCH 54:
# avg_loss: 12.52880
# EPOCH 55:
# avg_loss: 12.49521
# EPOCH 56:
# avg_loss: 12.46962
# EPOCH 57:
# avg_loss: 12.45275
# EPOCH 58:
# avg_loss: 12.43511
# EPOCH 59:
# avg_loss: 12.43207
# EPOCH 60:
# avg_loss: 12.42066
# EPOCH 61:
# avg_loss: 12.41620
# EPOCH 62:
# avg_loss: 12.40501
# EPOCH 63:
# avg_loss: 12.40195
# EPOCH 64:
# avg_loss: 12.40197
# EPOCH 65:
# avg_loss: 12.38778
# EPOCH 66:
# avg_loss: 12.39524
# EPOCH 67:
# avg_loss: 12.38660
# EPOCH 68:
# avg_loss: 12.38329
# EPOCH 69:
# avg_loss: 12.38067
# EPOCH 70:
# avg_loss: 12.37243
# EPOCH 71:
# avg_loss: 12.37531
# EPOCH 72:
# avg_loss: 12.37658
# EPOCH 73:
# avg_loss: 12.36645
# EPOCH 74:
# avg_loss: 12.36858
# EPOCH 75:
# avg_loss: 12.36974
# EPOCH 76:
# avg_loss: 12.36574
# EPOCH 77:
# avg_loss: 12.36700
# EPOCH 78:
# avg_loss: 12.37084
# EPOCH 79:
# avg_loss: 12.36311
# EPOCH 80:
# avg_loss: 12.36843
# EPOCH 81:
# avg_loss: 12.36686
# EPOCH 82:
# avg_loss: 12.36793
# EPOCH 83:
# avg_loss: 12.36313
# EPOCH 84:
# avg_loss: 12.37304
# EPOCH 85:
# avg_loss: 12.36928
# EPOCH 86:
# avg_loss: 12.36821
# EPOCH 87:
# avg_loss: 12.36109
# EPOCH 88:
# avg_loss: 12.36519
# EPOCH 89:
# avg_loss: 12.35913
# EPOCH 90:
# avg_loss: 12.36654
# EPOCH 91:
# avg_loss: 12.36246
# EPOCH 92:
# avg_loss: 12.36847
# EPOCH 93:
# avg_loss: 12.36399
# EPOCH 94:
# avg_loss: 12.36060
# EPOCH 95:
# avg_loss: 12.35852
# EPOCH 96:
# avg_loss: 12.36206
# EPOCH 97:
# avg_loss: 12.35709
# EPOCH 98:
# avg_loss: 12.36059
# EPOCH 99:
# avg_loss: 12.36589
# EPOCH 100:
# avg_loss: 12.36099
# Execution time: 60.125498 seconds
# baseline average loss:  0.13954019807707305
# baseline repeat:  0.19540230364635072
# regression loss total:  0.12597633930704782
# model loss total:  0.12214460223913193
#
# baseline average loss predindex:  0.21547522832607402
# baseline repeat predindex:  0.367816091954023
# regression loss predindex:  0.21619645753763092
# model loss predindex:  0.1902940720319748
# Train size:  791
#
# Val size:  87
#
# Number of Parameters 256
# EPOCH 1:
# avg_loss: 18.28565
# EPOCH 2:
# avg_loss: 14.32810
# EPOCH 3:
# avg_loss: 13.93089
# EPOCH 4:
# avg_loss: 13.71938
# EPOCH 5:
# avg_loss: 13.59940
# EPOCH 6:
# avg_loss: 13.53396
# EPOCH 7:
# avg_loss: 13.47309
# EPOCH 8:
# avg_loss: 13.43667
# EPOCH 9:
# avg_loss: 13.42275
# EPOCH 10:
# avg_loss: 13.39739
# EPOCH 11:
# avg_loss: 13.38057
# EPOCH 12:
# avg_loss: 13.37059
# EPOCH 13:
# avg_loss: 13.35550
# EPOCH 14:
# avg_loss: 13.34875
# EPOCH 15:
# avg_loss: 13.32019
# EPOCH 16:
# avg_loss: 13.26193
# EPOCH 17:
# avg_loss: 13.18461
# EPOCH 18:
# avg_loss: 13.12137
# EPOCH 19:
# avg_loss: 13.06902
# EPOCH 20:
# avg_loss: 13.04960
# EPOCH 21:
# avg_loss: 13.03280
# EPOCH 22:
# avg_loss: 13.03256
# EPOCH 23:
# avg_loss: 13.02472
# EPOCH 24:
# avg_loss: 13.01676
# EPOCH 25:
# avg_loss: 13.01105
# EPOCH 26:
# avg_loss: 13.00286
# EPOCH 27:
# avg_loss: 12.99519
# EPOCH 28:
# avg_loss: 12.99211
# EPOCH 29:
# avg_loss: 12.97898
# EPOCH 30:
# avg_loss: 12.97210
# EPOCH 31:
# avg_loss: 12.95598
# EPOCH 32:
# avg_loss: 12.93094
# EPOCH 33:
# avg_loss: 12.91325
# EPOCH 34:
# avg_loss: 12.88669
# EPOCH 35:
# avg_loss: 12.85955
# EPOCH 36:
# avg_loss: 12.84747
# EPOCH 37:
# avg_loss: 12.82447
# EPOCH 38:
# avg_loss: 12.82124
# EPOCH 39:
# avg_loss: 12.80317
# EPOCH 40:
# avg_loss: 12.79421
# EPOCH 41:
# avg_loss: 12.78826
# EPOCH 42:
# avg_loss: 12.77703
# EPOCH 43:
# avg_loss: 12.77184
# EPOCH 44:
# avg_loss: 12.76063
# EPOCH 45:
# avg_loss: 12.76312
# EPOCH 46:
# avg_loss: 12.75722
# EPOCH 47:
# avg_loss: 12.75522
# EPOCH 48:
# avg_loss: 12.74555
# EPOCH 49:
# avg_loss: 12.74084
# EPOCH 50:
# avg_loss: 12.73746
# EPOCH 51:
# avg_loss: 12.73094
# EPOCH 52:
# avg_loss: 12.72817
# EPOCH 53:
# avg_loss: 12.72514
# EPOCH 54:
# avg_loss: 12.72364
# EPOCH 55:
# avg_loss: 12.70132
# EPOCH 56:
# avg_loss: 12.67486
# EPOCH 57:
# avg_loss: 12.63461
# EPOCH 58:
# avg_loss: 12.59317
# EPOCH 59:
# avg_loss: 12.56481
# EPOCH 60:
# avg_loss: 12.52090
# EPOCH 61:
# avg_loss: 12.48507
# EPOCH 62:
# avg_loss: 12.46242
# EPOCH 63:
# avg_loss: 12.44956
# EPOCH 64:
# avg_loss: 12.42723
# EPOCH 65:
# avg_loss: 12.42509
# EPOCH 66:
# avg_loss: 12.40945
# EPOCH 67:
# avg_loss: 12.39962
# EPOCH 68:
# avg_loss: 12.38532
# EPOCH 69:
# avg_loss: 12.37739
# EPOCH 70:
# avg_loss: 12.37462
# EPOCH 71:
# avg_loss: 12.36854
# EPOCH 72:
# avg_loss: 12.36290
# EPOCH 73:
# avg_loss: 12.35864
# EPOCH 74:
# avg_loss: 12.35038
# EPOCH 75:
# avg_loss: 12.35014
# EPOCH 76:
# avg_loss: 12.34030
# EPOCH 77:
# avg_loss: 12.33929
# EPOCH 78:
# avg_loss: 12.34181
# EPOCH 79:
# avg_loss: 12.33756
# EPOCH 80:
# avg_loss: 12.33821
# EPOCH 81:
# avg_loss: 12.33678
# EPOCH 82:
# avg_loss: 12.33474
# EPOCH 83:
# avg_loss: 12.33376
# EPOCH 84:
# avg_loss: 12.33341
# EPOCH 85:
# avg_loss: 12.33040
# EPOCH 86:
# avg_loss: 12.33883
# EPOCH 87:
# avg_loss: 12.32712
# EPOCH 88:
# avg_loss: 12.32815
# EPOCH 89:
# avg_loss: 12.33119
# EPOCH 90:
# avg_loss: 12.33256
# EPOCH 91:
# avg_loss: 12.33069
# EPOCH 92:
# avg_loss: 12.32097
# EPOCH 93:
# avg_loss: 12.32905
# EPOCH 94:
# avg_loss: 12.33200
# EPOCH 95:
# avg_loss: 12.32356
# EPOCH 96:
# avg_loss: 12.32950
# EPOCH 97:
# avg_loss: 12.32580
# EPOCH 98:
# avg_loss: 12.32338
# EPOCH 99:
# avg_loss: 12.32437
# EPOCH 100:
# avg_loss: 12.32884
# Execution time: 62.273318 seconds
# baseline average loss:  0.1449864966602161
# baseline repeat:  0.20919540592993813
# regression loss total:  0.13684807552689016
# model loss total:  0.13270719349384308
#
# baseline average loss predindex:  0.18423849138720283
# baseline repeat predindex:  0.2988505747126437
# regression loss predindex:  0.1822520095995293
# model loss predindex:  0.16819056868553162
