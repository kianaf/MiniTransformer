# %%
import torch
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
# torch.multiprocessing.set_start_method('spawn', force=True)
import time
import importlib
import torch.optim as optim
from torchsummary import summary
import os
import statistics

os.chdir("../")
from src.data_preparation import SimulatedDataset, collate_function, load_real_data
from src.transformers import MiniTransformer
import src.transformers as transformerFunctions
from src.transformers import init_weights_recursive
from src.transformers import print_parameters
from src.transformers import create_custom_mask_pair, create_custom_mask_pred, create_distance_to_end_matrix, create_pairwise_distance_matrix
from src.evaluation import calculate_bench1_loss, calculate_bench2_loss, calculate_repeat_loss, calculate_regression_loss, evaluate_mini_transformer
from src.statistical_testing import statistical_testing, print_p_values, plot_context_predindex_pair_effect, get_context_predindex_pair_effect
import torch.autograd.profiler as profiler
from sklearn.model_selection import KFold
device = torch.device("cpu")

# %%
if __name__ == '__main__':
    
    bench_repeat_loss_list = []
    regression_loss_total_list = []
    model_loss_total_list = []
    regression_loss_predindex_list = []
    model_loss_predindex_list = []
    bench1_loss_list = []
    bench2_loss_list = []
    bench2loss_predindex_list = []
    bench_repeat_loss_predindex_list = []
    benchloss_predindex_list = []
    models = []
    


    # Hyperparameters
    # data_str = "ghq_b_sum"
    data_str = "ghq_sum"
    # data_str = "simulation"
    batch_size = 2          # Batch size for loading data
    dk = 1                  # d_k
    dv = 1                  # d_v
    nheads = 8             # number of heads
    ncum = 8                 # number of cumulants
    maxlen = 10             # maximum length of the sequence
    learning_rate = 1e-3
    lambda_l2 = 1e-3
    EPOCHS = 100
    target_sample_size = 7
    nrepp = 10
    seeds = [0, 1, 11, 42, 123, 999, 1337, 2025, 9999, 12345]
    
    k_for_cross_val = 10
    
    # load real data
    data, maxlen = load_real_data(data_str)
    
    
    # Create the KFold splitter:
    kf = KFold(n_splits=k_for_cross_val, shuffle=True, random_state=42)

    # Build a list of (train, eval) folds:
    folds = []
    for train_index, eval_index in kf.split(data):
        train_data = [data[i] for i in train_index]
        eval_data  = [data[i] for i in eval_index]
        folds.append((train_data, eval_data))
    
    
    
    for (train, val) in folds:
        
        # Set the random seed for reproducibility
        torch.manual_seed(42)


        
        n = len(train)
        p = train[0].shape[1]
        print("Train size: ", len(train), "\n")
        print("Val size: ", len(val), "\n")
        
        train_dataset = train
        eval_dataset = val
        predindex = 9

        

        mask_pairwise = create_custom_mask_pair(maxlen, device)
        distance_to_end_matrix = create_distance_to_end_matrix(maxlen, device)
        pairwise_distance_matrix = create_pairwise_distance_matrix(maxlen, device)

    
        dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_function,  num_workers=0)
        eval_dataloader = DataLoader(eval_dataset, batch_size=len(eval_dataset), shuffle=False, collate_fn=collate_function, num_workers=0)
       
       
        model = MiniTransformer(p, nheads, dk, dv, ncum, mask_pairwise, pairwise_distance_matrix, distance_to_end_matrix,  device)

        model.apply(init_weights_recursive)
        model.to(device)

        # model = torch.compile(model)
        # Start the timer
        start_time = time.time()

        # Define optimizer
        # optimizer = optim.Adam(model.parameters(), lr= learning_rate, weight_decay=lambda_l2)
        optimizer = optim.Adam(model.parameters(), lr= learning_rate)
        
        print("Number of Parameters", transformerFunctions.count_parameters(model))
        
        run_path = transformerFunctions.train_mini_transformer(model, dataloader, eval_dataloader, optimizer, lambda_l2, EPOCHS, device)


        # # Enable profiling
        # with profiler.profile() as prof:

        #     model.eval() 
        #     # Forward pass
        #     output = model(train_dataset.data)
        #     # Backward pass (this will profile the backward pass as well)
        #     output.backward(torch.ones_like(output))

        # # Print profiling results
        # print(prof.key_averages().table(sort_by="cpu_time_total", row_limit=10))



        # End the timer
        end_time = time.time()

        # Calculate and print the execution time
        execution_time = end_time - start_time 
        print(f"Execution time: {execution_time:.6f} seconds")


        
        
        
        # Evaluate the model
        
        eval_dataloader = DataLoader(eval_dataset, batch_size=1, shuffle=False, collate_fn=collate_function, num_workers=0)
       
    
    
        dimave, bench1_loss, benchloss_predindex = calculate_bench1_loss(train_dataset, eval_dataset, predindex)
        regression_loss_predindex, regression_loss_total = calculate_regression_loss(train_dataset, eval_dataset, predindex)
        model_loss_predindex, model_loss_total = evaluate_mini_transformer(eval_dataloader, model, predindex)
        
        
        print("baseline average loss: ", bench1_loss)

        
        # Evaluate the model
        if data_str == "simulation":
            bench2loss, bench2loss_predindex = calculate_bench2_loss(train_dataset, eval_dataset, dimave)
            print("baseline informed loss: ", bench2loss)
            bench2_loss_list.append(bench2loss)
            bench2loss_predindex_list.append(bench2loss_predindex)
            
        else:
            bench_repeat, bench_repeat_predindex = calculate_repeat_loss(eval_dataset, predindex)    
            print("baseline repeat: ", bench_repeat)
            
            
            
        print("regression loss total: ", regression_loss_total)
        print("model loss total: ", model_loss_total.item(), "\n") 
        
        
        if data_str == "simulation":
            print("baseline informed loss predindex: ", bench2loss_predindex)
            bench2loss_predindex_list.append(bench2loss_predindex)
            
        print("baseline average loss predindex: ", benchloss_predindex)
        print("baseline repeat predindex: ", bench_repeat_predindex)    
        print("regression loss predindex: ", regression_loss_predindex)
        print("model loss predindex: ", model_loss_predindex.item()) 


        
        
        bench_repeat_loss_list.append(bench_repeat)
        regression_loss_total_list.append(regression_loss_total)
        model_loss_total_list.append(model_loss_total.item())
        benchloss_predindex_list.append(benchloss_predindex)
        bench_repeat_loss_predindex_list.append(bench_repeat_predindex)
        regression_loss_predindex_list.append(regression_loss_predindex)
        model_loss_predindex_list.append(model_loss_predindex.item())
        bench1_loss_list.append(bench1_loss)
        
        
        
# save the mean and std of these lists in text file in the format of mean ± std 
# os.chdir("./notebooks/results")




with open(f"./notebooks/pred_{data_str}_results_n={n}_batch_size={batch_size}_p={p}_ncum={ncum}_nheads={nheads}_epochs={EPOCHS}.txt", "a") as f:
    # First line
    f.write(f"{data_str} results n = {n}\n")

    # Single-line writes with three-decimal formatting:
    f.write(f"baseline repeat: {statistics.mean(bench_repeat_loss_list):.3f} ± {statistics.stdev(bench_repeat_loss_list):.3f}\n")
    f.write(f"baseline average loss: {statistics.mean(bench1_loss_list):.3f} ± {statistics.stdev(bench1_loss_list):.3f}\n")
    if data_str == "simulation":
        f.write(f"baseline informed loss: {statistics.mean(bench2_loss_list):.3f} ± {statistics.stdev(bench2_loss_list):.3f}\n")
        
    f.write(f"regression loss total: {statistics.mean(regression_loss_total_list):.3f} ± {statistics.stdev(regression_loss_total_list):.3f}\n")
    f.write(f"model loss total: {statistics.mean(model_loss_total_list):.3f} ± {statistics.stdev(model_loss_total_list):.3f}\n\n")

    
    f.write(f"baseline repeat predindex: {statistics.mean(bench_repeat_loss_predindex_list):.3f} ± {statistics.stdev(bench_repeat_loss_list):.3f}\n")
    f.write(f"baseline average loss predindex: {statistics.mean(benchloss_predindex_list):.3f} ± {statistics.stdev(benchloss_predindex_list):.3f}\n")
    f.write(f"regression loss predindex: {statistics.mean(regression_loss_predindex_list):.3f} ± {statistics.stdev(regression_loss_predindex_list):.3f}\n")
    if data_str == "simulation":
        f.write(f"baseline informed loss predindex: {statistics.mean(bench2loss_predindex_list):.3f} ± {statistics.stdev(bench2loss_predindex_list):.3f}\n")
    f.write(f"model loss predindex: {statistics.mean(model_loss_predindex_list):.3f} ± {statistics.stdev(model_loss_predindex_list):.3f}\n")

    # Extra newlines at the end
    f.write("\n\n")
# Out:
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss_train: 16.64508
# avg_loss_val: 14.25819
# EPOCH 11:
# avg_loss_train: 12.61417
# avg_loss_val: 13.06595
# EPOCH 21:
# avg_loss_train: 12.29836
# avg_loss_val: 12.81376
# EPOCH 31:
# avg_loss_train: 12.24278
# avg_loss_val: 12.83313
# EPOCH 41:
# avg_loss_train: 12.21345
# avg_loss_val: 12.82529
# EPOCH 51:
# avg_loss_train: 12.20774
# avg_loss_val: 12.82392
# EPOCH 61:
# avg_loss_train: 12.21175
# avg_loss_val: 12.84188
# EPOCH 71:
# avg_loss_train: 12.21654
# avg_loss_val: 12.84517
# EPOCH 81:
# avg_loss_train: 12.22559
# avg_loss_val: 12.83109
# EPOCH 91:
# avg_loss_train: 12.23320
# avg_loss_val: 12.88545
# Execution time: 43.761218 seconds
# baseline average loss:  0.15859759196808393
# baseline repeat:  0.21477273148907858
# regression loss total:  0.14276478477855387
# model loss total:  0.14166364073753357
#
# baseline average loss predindex:  0.2244398214600303
# baseline repeat predindex:  0.2840909090909091
# regression loss predindex:  0.1904359268614326
# model loss predindex:  0.18549871444702148
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss_train: 16.95557
# avg_loss_val: 13.53249
# EPOCH 11:
# avg_loss_train: 12.69505
# avg_loss_val: 12.26152
# EPOCH 21:
# avg_loss_train: 12.40546
# avg_loss_val: 11.97418
# EPOCH 31:
# avg_loss_train: 12.34344
# avg_loss_val: 11.91112
# EPOCH 41:
# avg_loss_train: 12.30937
# avg_loss_val: 11.91997
# EPOCH 51:
# avg_loss_train: 12.30716
# avg_loss_val: 11.93246
# EPOCH 61:
# avg_loss_train: 12.30932
# avg_loss_val: 11.92737
# EPOCH 71:
# avg_loss_train: 12.29476
# avg_loss_val: 11.93092
# EPOCH 81:
# avg_loss_train: 12.28816
# avg_loss_val: 11.89941
# EPOCH 91:
# avg_loss_train: 12.29537
# avg_loss_val: 11.93248
# Execution time: 64.591905 seconds
# baseline average loss:  0.14526255001229318
# baseline repeat:  0.18068182205950672
# regression loss total:  0.121073489383054
# model loss total:  0.11469865590333939
#
# baseline average loss predindex:  0.19834864139556885
# baseline repeat predindex:  0.1590909090909091
# regression loss predindex:  0.1363007399193434
# model loss predindex:  0.12770883738994598
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss_train: 17.18443
# avg_loss_val: 12.77540
# EPOCH 11:
# avg_loss_train: 12.67865
# avg_loss_val: 11.84865
# EPOCH 21:
# avg_loss_train: 12.43331
# avg_loss_val: 11.66791
# EPOCH 31:
# avg_loss_train: 12.35713
# avg_loss_val: 11.64618
# EPOCH 41:
# avg_loss_train: 12.33589
# avg_loss_val: 11.67741
# EPOCH 51:
# avg_loss_train: 12.33347
# avg_loss_val: 11.61699
# EPOCH 61:
# avg_loss_train: 12.34324
# avg_loss_val: 11.63500
# EPOCH 71:
# avg_loss_train: 12.34476
# avg_loss_val: 11.65423
# EPOCH 81:
# avg_loss_train: 12.33880
# avg_loss_val: 11.66428
# EPOCH 91:
# avg_loss_train: 12.33047
# avg_loss_val: 11.65196
# Execution time: 55.610865 seconds
# baseline average loss:  0.1499276178550314
# baseline repeat:  0.23068182297389617
# regression loss total:  0.1358609797984465
# model loss total:  0.13360995054244995
#
# baseline average loss predindex:  0.19835196841846814
# baseline repeat predindex:  0.3522727272727273
# regression loss predindex:  0.20026124068018383
# model loss predindex:  0.21284829080104828
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss_train: 16.85753
# avg_loss_val: 14.40824
# EPOCH 11:
# avg_loss_train: 12.70015
# avg_loss_val: 13.45701
# EPOCH 21:
# avg_loss_train: 12.38389
# avg_loss_val: 13.27531
# EPOCH 31:
# avg_loss_train: 12.25734
# avg_loss_val: 13.15496
# EPOCH 41:
# avg_loss_train: 12.18586
# avg_loss_val: 13.16483
# EPOCH 51:
# avg_loss_train: 12.18066
# avg_loss_val: 13.16522
# EPOCH 61:
# avg_loss_train: 12.18395
# avg_loss_val: 13.18837
# EPOCH 71:
# avg_loss_train: 12.18968
# avg_loss_val: 13.18134
# EPOCH 81:
# avg_loss_train: 12.19289
# avg_loss_val: 13.20758
# EPOCH 91:
# avg_loss_train: 12.18651
# avg_loss_val: 13.27952
# Execution time: 47.677496 seconds
# baseline average loss:  0.1582697843286124
# baseline repeat:  0.23863636829297652
# regression loss total:  0.14877931341633457
# model loss total:  0.14330913126468658
#
# baseline average loss predindex:  0.22378400882536714
# baseline repeat predindex:  0.32954545454545453
# regression loss predindex:  0.21317685548804696
# model loss predindex:  0.20762532949447632
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss_train: 16.74863
# avg_loss_val: 14.17580
# EPOCH 11:
# avg_loss_train: 12.60386
# avg_loss_val: 13.26515
# EPOCH 21:
# avg_loss_train: 12.29700
# avg_loss_val: 12.91699
# EPOCH 31:
# avg_loss_train: 12.26638
# avg_loss_val: 12.84081
# EPOCH 41:
# avg_loss_train: 12.22847
# avg_loss_val: 12.79591
# EPOCH 51:
# avg_loss_train: 12.21151
# avg_loss_val: 12.78786
# EPOCH 61:
# avg_loss_train: 12.21340
# avg_loss_val: 12.80548
# EPOCH 71:
# avg_loss_train: 12.21632
# avg_loss_val: 12.82885
# EPOCH 81:
# avg_loss_train: 12.22087
# avg_loss_val: 12.83550
# EPOCH 91:
# avg_loss_train: 12.22317
# avg_loss_val: 12.79948
# Execution time: 43.770786 seconds
# baseline average loss:  0.1490945308469236
# baseline repeat:  0.18295454962009733
# regression loss total:  0.1261951253998941
# model loss total:  0.12586794793605804
#
# baseline average loss predindex:  0.19321499646387316
# baseline repeat predindex:  0.32954545454545453
# regression loss predindex:  0.18515294761453258
# model loss predindex:  0.1827276200056076
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss_train: 17.15917
# avg_loss_val: 12.68590
# EPOCH 11:
# avg_loss_train: 12.69268
# avg_loss_val: 11.86269
# EPOCH 21:
# avg_loss_train: 12.42120
# avg_loss_val: 11.75060
# EPOCH 31:
# avg_loss_train: 12.37158
# avg_loss_val: 11.68204
# EPOCH 41:
# avg_loss_train: 12.33480
# avg_loss_val: 11.65489
# EPOCH 51:
# avg_loss_train: 12.33802
# avg_loss_val: 11.69279
# EPOCH 61:
# avg_loss_train: 12.33560
# avg_loss_val: 11.68919
# EPOCH 71:
# avg_loss_train: 12.32345
# avg_loss_val: 11.71521
# EPOCH 81:
# avg_loss_train: 12.32550
# avg_loss_val: 11.72537
# EPOCH 91:
# avg_loss_train: 12.31767
# avg_loss_val: 11.73955
# Execution time: 41.354813 seconds
# baseline average loss:  0.14966008625924587
# baseline repeat:  0.2261363681913777
# regression loss total:  0.137947379549421
# model loss total:  0.13107182085514069
#
# baseline average loss predindex:  0.2034634706479582
# baseline repeat predindex:  0.26136363636363635
# regression loss predindex:  0.17850801415634893
# model loss predindex:  0.1687968522310257
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss_train: 17.03622
# avg_loss_val: 13.21971
# EPOCH 11:
# avg_loss_train: 12.70647
# avg_loss_val: 12.50480
# EPOCH 21:
# avg_loss_train: 12.42768
# avg_loss_val: 12.26489
# EPOCH 31:
# avg_loss_train: 12.33740
# avg_loss_val: 12.17505
# EPOCH 41:
# avg_loss_train: 12.30710
# avg_loss_val: 12.20106
# EPOCH 51:
# avg_loss_train: 12.27143
# avg_loss_val: 12.17884
# EPOCH 61:
# avg_loss_train: 12.27542
# avg_loss_val: 12.23676
# EPOCH 71:
# avg_loss_train: 12.28477
# avg_loss_val: 12.19291
# EPOCH 81:
# avg_loss_train: 12.29048
# avg_loss_val: 12.18923
# EPOCH 91:
# avg_loss_train: 12.28393
# avg_loss_val: 12.27690
# Execution time: 41.436889 seconds
# baseline average loss:  0.14734210454943505
# baseline repeat:  0.22500000419941815
# regression loss total:  0.13874017527501298
# model loss total:  0.13726140558719635
#
# baseline average loss predindex:  0.2443298101425171
# baseline repeat predindex:  0.2727272727272727
# regression loss predindex:  0.20511598438644646
# model loss predindex:  0.20428134500980377
# Train size:  790
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss_train: 17.11402
# avg_loss_val: 12.55871
# EPOCH 11:
# avg_loss_train: 12.78945
# avg_loss_val: 11.97267
# EPOCH 21:
# avg_loss_train: 12.49297
# avg_loss_val: 11.83062
# EPOCH 31:
# avg_loss_train: 12.38239
# avg_loss_val: 11.70861
# EPOCH 41:
# avg_loss_train: 12.34808
# avg_loss_val: 11.68344
# EPOCH 51:
# avg_loss_train: 12.34553
# avg_loss_val: 11.65650
# EPOCH 61:
# avg_loss_train: 12.33643
# avg_loss_val: 11.67215
# EPOCH 71:
# avg_loss_train: 12.34330
# avg_loss_val: 11.73328
# EPOCH 81:
# avg_loss_train: 12.34000
# avg_loss_val: 11.67919
# EPOCH 91:
# avg_loss_train: 12.34213
# avg_loss_val: 11.68674
# Execution time: 50.036266 seconds
# baseline average loss:  0.14695440884679556
# baseline repeat:  0.2125000050291419
# regression loss total:  0.13619163716746993
# model loss total:  0.132660910487175
#
# baseline average loss predindex:  0.19835067337209528
# baseline repeat predindex:  0.32954545454545453
# regression loss predindex:  0.19736180993940725
# model loss predindex:  0.18554331362247467
# Train size:  791
#
# Val size:  87
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss_train: 17.04544
# avg_loss_val: 13.94376
# EPOCH 11:
# avg_loss_train: 12.51873
# avg_loss_val: 12.90750
# EPOCH 21:
# avg_loss_train: 12.35151
# avg_loss_val: 12.75986
# EPOCH 31:
# avg_loss_train: 12.29762
# avg_loss_val: 12.68217
# EPOCH 41:
# avg_loss_train: 12.24399
# avg_loss_val: 12.66533
# EPOCH 51:
# avg_loss_train: 12.22245
# avg_loss_val: 12.60171
# EPOCH 61:
# avg_loss_train: 12.22211
# avg_loss_val: 12.65947
# EPOCH 71:
# avg_loss_train: 12.22439
# avg_loss_val: 12.63265
# EPOCH 81:
# avg_loss_train: 12.21370
# avg_loss_val: 12.66488
# EPOCH 91:
# avg_loss_train: 12.21446
# avg_loss_val: 12.69635
# Execution time: 45.787599 seconds
# baseline average loss:  0.13954019807707305
# baseline repeat:  0.19540230364635072
# regression loss total:  0.12597633930704782
# model loss total:  0.11764758825302124
#
# baseline average loss predindex:  0.21547522832607402
# baseline repeat predindex:  0.367816091954023
# regression loss predindex:  0.21619645753763092
# model loss predindex:  0.1963023692369461
# Train size:  791
#
# Val size:  87
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss_train: 17.23669
# avg_loss_val: 14.31883
# EPOCH 11:
# avg_loss_train: 12.56405
# avg_loss_val: 13.46270
# EPOCH 21:
# avg_loss_train: 12.26167
# avg_loss_val: 13.18752
# EPOCH 31:
# avg_loss_train: 12.23100
# avg_loss_val: 13.18671
# EPOCH 41:
# avg_loss_train: 12.18041
# avg_loss_val: 13.14524
# EPOCH 51:
# avg_loss_train: 12.19301
# avg_loss_val: 13.18284
# EPOCH 61:
# avg_loss_train: 12.19223
# avg_loss_val: 13.16920
# EPOCH 71:
# avg_loss_train: 12.16998
# avg_loss_val: 13.17486
# EPOCH 81:
# avg_loss_train: 12.16569
# avg_loss_val: 13.20408
# EPOCH 91:
# avg_loss_train: 12.17663
# avg_loss_val: 13.20147
# Execution time: 41.628623 seconds
# baseline average loss:  0.1449864966602161
# baseline repeat:  0.20919540592993813
# regression loss total:  0.13684807552689016
# model loss total:  0.13297683000564575
#
# baseline average loss predindex:  0.18423849138720283
# baseline repeat predindex:  0.2988505747126437
# regression loss predindex:  0.1822520095995293
# model loss predindex:  0.1675998568534851
