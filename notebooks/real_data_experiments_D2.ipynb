# %%
import torch
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
# torch.multiprocessing.set_start_method('spawn', force=True)
import time
import importlib
import torch.optim as optim
from torchsummary import summary
import os
import statistics

os.chdir("../")
from src.data_preparation import SimulatedDataset, collate_function, load_real_data
from src.transformers import MiniTransformer
import src.transformers as transformerFunctions
from src.transformers import init_weights_recursive
from src.transformers import print_parameters
from src.transformers import create_custom_mask, create_distance_to_end_matrix, create_pairwise_distance_matrix
from src.evaluation import calculate_bench1_loss, calculate_bench2_loss, calculate_repeat_loss, calculate_regression_loss, evaluate_mini_transformer
from src.statistical_testing import statistical_testing, print_p_values, plot_context_predindex_pair_effect, get_context_predindex_pair_effect
import torch.autograd.profiler as profiler
from sklearn.model_selection import KFold
device = torch.device("cpu")

# %%
if __name__ == '__main__':
    
    bench_repeat_loss_list = []
    regression_loss_total_list = []
    model_loss_total_list = []
    regression_loss_predindex_list = []
    model_loss_predindex_list = []
    bench1_loss_list = []
    bench2_loss_list = []
    bench2loss_predindex_list = []
    models = []
    


    # Hyperparameters
    data_str = "ghq_b_sum"
    # data_str = "ghq_sum"
    # data_str = "simulation"
    batch_size = 1          # Batch size for loading data
    dk = 1                  # d_k
    dv = 1                  # d_v
    nheads = 8             # number of heads
    ncum = 8                 # number of cumulants
    maxlen = 10             # maximum length of the sequence
    learning_rate = 1e-3
    lambda_l2 = 1e-3
    EPOCHS = 100
    target_sample_size = 7
    nrepp = 10
    seeds = [0, 1, 11, 42, 123, 999, 1337, 2025, 9999, 12345]
    
    k_for_cross_val = 10
    
    # load real data
    data, maxlen = load_real_data(data_str)
    
    
    # Create the KFold splitter:
    kf = KFold(n_splits=k_for_cross_val, shuffle=True, random_state=42)

    # Build a list of (train, eval) folds:
    folds = []
    for train_index, eval_index in kf.split(data):
        train_data = [data[i] for i in train_index]
        eval_data  = [data[i] for i in eval_index]
        folds.append((train_data, eval_data))
    
    
    
    for (train, val) in folds:
        
        # Set the random seed for reproducibility
        torch.manual_seed(42)


        
        n = len(train)
        p = train[0].shape[1]
        print("Train size: ", len(train), "\n")
        print("Val size: ", len(val), "\n")
        
        train_dataset = train
        eval_dataset = val
        predindex = 9

        

        mask = create_custom_mask(maxlen, device)
        distance_to_end_matrix = create_distance_to_end_matrix(maxlen, device)
        pairwise_distance_matrix = create_pairwise_distance_matrix(maxlen, device)

    
        dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_function,  num_workers=0)
        
        model = MiniTransformer(p, nheads, dk, dv, ncum, mask, pairwise_distance_matrix, distance_to_end_matrix,  device)

        model.apply(init_weights_recursive)
        model.to(device)

        # model = torch.compile(model)
        # Start the timer
        start_time = time.time()

        # Define optimizer
        # optimizer = optim.Adam(model.parameters(), lr= learning_rate, weight_decay=lambda_l2)
        optimizer = optim.Adam(model.parameters(), lr= learning_rate)
        
        print("Number of Parameters", transformerFunctions.count_parameters(model))
        
        run_path = transformerFunctions.train_mini_transformer(model, dataloader, optimizer, lambda_l2, EPOCHS, device)


        # # Enable profiling
        # with profiler.profile() as prof:

        #     model.eval() 
        #     # Forward pass
        #     output = model(train_dataset.data)
        #     # Backward pass (this will profile the backward pass as well)
        #     output.backward(torch.ones_like(output))

        # # Print profiling results
        # print(prof.key_averages().table(sort_by="cpu_time_total", row_limit=10))



        # End the timer
        end_time = time.time()

        # Calculate and print the execution time
        execution_time = end_time - start_time 
        print(f"Execution time: {execution_time:.6f} seconds")


        
        
        
        # Evaluate the model
        
        eval_dataloader = DataLoader(eval_dataset, batch_size=1, shuffle=True, collate_fn=collate_function, num_workers=0)
       
    
    
        dimave, bench1_loss = calculate_bench1_loss(train_dataset, eval_dataset)
        regression_loss_predindex, regression_loss_total = calculate_regression_loss(train_dataset, eval_dataset, predindex)
        model_loss_predindex, model_loss_total = evaluate_mini_transformer(eval_dataloader, model, predindex)
        
        
        print("baseline average loss: ", bench1_loss)

        
        # Evaluate the model
        if data_str == "simulation":
            bench2loss, bench2loss_predindex = calculate_bench2_loss(train_dataset, eval_dataset, dimave)
            print("baseline informed loss: ", bench2loss)
            bench2_loss_list.append(bench2loss)
            bench2loss_predindex_list.append(bench2loss_predindex)
            
        else:
            bench_repeat = calculate_repeat_loss(eval_dataset)    
            print("baseline repeat: ", bench_repeat)
            bench_repeat_loss_list.append(bench_repeat)
            
            
        print("regression loss total: ", regression_loss_total)
        print("model loss total: ", model_loss_total.item(), "\n") 
        
        
        if data_str == "simulation":
            print("baseline informed loss predindex: ", bench2loss_predindex)
            
        print("regression loss predindex: ", regression_loss_predindex)
        print("model loss predindex: ", model_loss_predindex.item()) 

        
        regression_loss_total_list.append(regression_loss_total)
        model_loss_total_list.append(model_loss_total.item())
        regression_loss_predindex_list.append(regression_loss_predindex)
        model_loss_predindex_list.append(model_loss_predindex.item())
        bench1_loss_list.append(bench1_loss)
        
        
        
# save the mean and std of these lists in text file in the format of mean ± std 
# os.chdir("./notebooks/results")



with open(f"./notebooks/{data_str}_results_n={n}.txt", "a") as f:
    # First line
    f.write(f"{data_str} results n = {n}\n")

    # Single-line writes with three-decimal formatting:
    f.write(f"baseline repeat: {statistics.mean(bench_repeat_loss_list):.3f} ± {statistics.stdev(bench_repeat_loss_list):.3f}\n")
    f.write(f"baseline average loss: {statistics.mean(bench1_loss_list):.3f} ± {statistics.stdev(bench1_loss_list):.3f}\n")
    if data_str == "simulation":
        f.write(f"baseline informed loss: {statistics.mean(bench2_loss_list):.3f} ± {statistics.stdev(bench2_loss_list):.3f}\n")
    f.write(f"regression loss total: {statistics.mean(regression_loss_total_list):.3f} ± {statistics.stdev(regression_loss_total_list):.3f}\n")
    f.write(f"model loss total: {statistics.mean(model_loss_total_list):.3f} ± {statistics.stdev(model_loss_total_list):.3f}\n\n")

    
    
    f.write(f"regression loss predindex: {statistics.mean(regression_loss_predindex_list):.3f} ± {statistics.stdev(regression_loss_predindex_list):.3f}\n")
    if data_str == "simulation":
        f.write(f"baseline informed loss predindex: {statistics.mean(bench2loss_predindex_list):.3f} ± {statistics.stdev(bench2loss_predindex_list):.3f}\n")
    f.write(f"model loss predindex: {statistics.mean(model_loss_predindex_list):.3f} ± {statistics.stdev(model_loss_predindex_list):.3f}\n")

    # Extra newlines at the end
    f.write("\n\n")
# Out:
# Train size:  793
#
# Val size:  89
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss: 20.89583
# EPOCH 2:
# avg_loss: 17.14776
# EPOCH 3:
# avg_loss: 16.55813
# EPOCH 4:
# avg_loss: 16.22212
# EPOCH 5:
# avg_loss: 16.02076
# EPOCH 6:
# avg_loss: 15.89257
# EPOCH 7:
# avg_loss: 15.80333
# EPOCH 8:
# avg_loss: 15.74800
# EPOCH 9:
# avg_loss: 15.70829
# EPOCH 10:
# avg_loss: 15.66935
# EPOCH 11:
# avg_loss: 15.59137
# EPOCH 12:
# avg_loss: 15.47364
# EPOCH 13:
# avg_loss: 15.32600
# EPOCH 14:
# avg_loss: 15.24047
# EPOCH 15:
# avg_loss: 15.18706
# EPOCH 16:
# avg_loss: 15.15964
# EPOCH 17:
# avg_loss: 15.12675
# EPOCH 18:
# avg_loss: 15.08143
# EPOCH 19:
# avg_loss: 15.03594
# EPOCH 20:
# avg_loss: 14.98432
# EPOCH 21:
# avg_loss: 14.91733
# EPOCH 22:
# avg_loss: 14.86019
# EPOCH 23:
# avg_loss: 14.83247
# EPOCH 24:
# avg_loss: 14.79334
# EPOCH 25:
# avg_loss: 14.77233
# EPOCH 26:
# avg_loss: 14.73768
# EPOCH 27:
# avg_loss: 14.71671
# EPOCH 28:
# avg_loss: 14.70189
# EPOCH 29:
# avg_loss: 14.68774
# EPOCH 30:
# avg_loss: 14.66979
# EPOCH 31:
# avg_loss: 14.66548
# EPOCH 32:
# avg_loss: 14.65368
# EPOCH 33:
# avg_loss: 14.65740
# EPOCH 34:
# avg_loss: 14.65026
# EPOCH 35:
# avg_loss: 14.63449
# EPOCH 36:
# avg_loss: 14.62889
# EPOCH 37:
# avg_loss: 14.60675
# EPOCH 38:
# avg_loss: 14.59433
# EPOCH 39:
# avg_loss: 14.56510
# EPOCH 40:
# avg_loss: 14.54862
# EPOCH 41:
# avg_loss: 14.51377
# EPOCH 42:
# avg_loss: 14.51034
# EPOCH 43:
# avg_loss: 14.50614
# EPOCH 44:
# avg_loss: 14.48714
# EPOCH 45:
# avg_loss: 14.48884
# EPOCH 46:
# avg_loss: 14.47750
# EPOCH 47:
# avg_loss: 14.46280
# EPOCH 48:
# avg_loss: 14.48044
# EPOCH 49:
# avg_loss: 14.47212
# EPOCH 50:
# avg_loss: 14.46565
# EPOCH 51:
# avg_loss: 14.46356
# EPOCH 52:
# avg_loss: 14.46479
# EPOCH 53:
# avg_loss: 14.46574
# EPOCH 54:
# avg_loss: 14.45694
# EPOCH 55:
# avg_loss: 14.44941
# EPOCH 56:
# avg_loss: 14.45646
# EPOCH 57:
# avg_loss: 14.44956
# EPOCH 58:
# avg_loss: 14.44650
# EPOCH 59:
# avg_loss: 14.43794
# EPOCH 60:
# avg_loss: 14.45123
# EPOCH 61:
# avg_loss: 14.43412
# EPOCH 62:
# avg_loss: 14.40198
# EPOCH 63:
# avg_loss: 14.35665
# EPOCH 64:
# avg_loss: 14.29917
# EPOCH 65:
# avg_loss: 14.23527
# EPOCH 66:
# avg_loss: 14.16396
# EPOCH 67:
# avg_loss: 14.08552
# EPOCH 68:
# avg_loss: 14.00881
# EPOCH 69:
# avg_loss: 13.93323
# EPOCH 70:
# avg_loss: 13.86171
# EPOCH 71:
# avg_loss: 13.80088
# EPOCH 72:
# avg_loss: 13.77015
# EPOCH 73:
# avg_loss: 13.74017
# EPOCH 74:
# avg_loss: 13.73253
# EPOCH 75:
# avg_loss: 13.72180
# EPOCH 76:
# avg_loss: 13.71585
# EPOCH 77:
# avg_loss: 13.71050
# EPOCH 78:
# avg_loss: 13.70495
# EPOCH 79:
# avg_loss: 13.69873
# EPOCH 80:
# avg_loss: 13.69418
# EPOCH 81:
# avg_loss: 13.69278
# EPOCH 82:
# avg_loss: 13.68526
# EPOCH 83:
# avg_loss: 13.68483
# EPOCH 84:
# avg_loss: 13.67545
# EPOCH 85:
# avg_loss: 13.66816
# EPOCH 86:
# avg_loss: 13.65911
# EPOCH 87:
# avg_loss: 13.63451
# EPOCH 88:
# avg_loss: 13.62797
# EPOCH 89:
# avg_loss: 13.61957
# EPOCH 90:
# avg_loss: 13.59888
# EPOCH 91:
# avg_loss: 13.58809
# EPOCH 92:
# avg_loss: 13.59008
# EPOCH 93:
# avg_loss: 13.58158
# EPOCH 94:
# avg_loss: 13.58529
# EPOCH 95:
# avg_loss: 13.58530
# EPOCH 96:
# avg_loss: 13.58466
# EPOCH 97:
# avg_loss: 13.58693
# EPOCH 98:
# avg_loss: 13.58086
# EPOCH 99:
# avg_loss: 13.58413
# EPOCH 100:
# avg_loss: 13.57927
# Execution time: 63.347616 seconds
# baseline average loss:  0.16300367940677685
# baseline repeat:  0.20674157678411248
# regression loss total:  0.1367801815925174
# model loss total:  0.13059289753437042
#
# regression loss predindex:  0.16274241639811407
# model loss predindex:  0.16559578478336334
# Train size:  793
#
# Val size:  89
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss: 21.15306
# EPOCH 2:
# avg_loss: 17.27497
# EPOCH 3:
# avg_loss: 16.68732
# EPOCH 4:
# avg_loss: 16.37055
# EPOCH 5:
# avg_loss: 16.16853
# EPOCH 6:
# avg_loss: 16.03900
# EPOCH 7:
# avg_loss: 15.95824
# EPOCH 8:
# avg_loss: 15.90390
# EPOCH 9:
# avg_loss: 15.86094
# EPOCH 10:
# avg_loss: 15.80893
# EPOCH 11:
# avg_loss: 15.71965
# EPOCH 12:
# avg_loss: 15.59852
# EPOCH 13:
# avg_loss: 15.46989
# EPOCH 14:
# avg_loss: 15.39026
# EPOCH 15:
# avg_loss: 15.34532
# EPOCH 16:
# avg_loss: 15.30577
# EPOCH 17:
# avg_loss: 15.27022
# EPOCH 18:
# avg_loss: 15.22946
# EPOCH 19:
# avg_loss: 15.17090
# EPOCH 20:
# avg_loss: 15.10662
# EPOCH 21:
# avg_loss: 15.03623
# EPOCH 22:
# avg_loss: 15.00428
# EPOCH 23:
# avg_loss: 14.97840
# EPOCH 24:
# avg_loss: 14.95287
# EPOCH 25:
# avg_loss: 14.93967
# EPOCH 26:
# avg_loss: 14.90433
# EPOCH 27:
# avg_loss: 14.87397
# EPOCH 28:
# avg_loss: 14.86047
# EPOCH 29:
# avg_loss: 14.85341
# EPOCH 30:
# avg_loss: 14.83570
# EPOCH 31:
# avg_loss: 14.82356
# EPOCH 32:
# avg_loss: 14.82708
# EPOCH 33:
# avg_loss: 14.82630
# EPOCH 34:
# avg_loss: 14.82421
# EPOCH 35:
# avg_loss: 14.81376
# EPOCH 36:
# avg_loss: 14.80708
# EPOCH 37:
# avg_loss: 14.80218
# EPOCH 38:
# avg_loss: 14.79665
# EPOCH 39:
# avg_loss: 14.79371
# EPOCH 40:
# avg_loss: 14.78553
# EPOCH 41:
# avg_loss: 14.76922
# EPOCH 42:
# avg_loss: 14.76182
# EPOCH 43:
# avg_loss: 14.74435
# EPOCH 44:
# avg_loss: 14.72367
# EPOCH 45:
# avg_loss: 14.69997
# EPOCH 46:
# avg_loss: 14.66578
# EPOCH 47:
# avg_loss: 14.62381
# EPOCH 48:
# avg_loss: 14.59768
# EPOCH 49:
# avg_loss: 14.58637
# EPOCH 50:
# avg_loss: 14.57846
# EPOCH 51:
# avg_loss: 14.57390
# EPOCH 52:
# avg_loss: 14.57276
# EPOCH 53:
# avg_loss: 14.56538
# EPOCH 54:
# avg_loss: 14.56211
# EPOCH 55:
# avg_loss: 14.55265
# EPOCH 56:
# avg_loss: 14.55224
# EPOCH 57:
# avg_loss: 14.55214
# EPOCH 58:
# avg_loss: 14.54715
# EPOCH 59:
# avg_loss: 14.53852
# EPOCH 60:
# avg_loss: 14.55030
# EPOCH 61:
# avg_loss: 14.54102
# EPOCH 62:
# avg_loss: 14.53930
# EPOCH 63:
# avg_loss: 14.53498
# EPOCH 64:
# avg_loss: 14.53053
# EPOCH 65:
# avg_loss: 14.52519
# EPOCH 66:
# avg_loss: 14.49816
# EPOCH 67:
# avg_loss: 14.43628
# EPOCH 68:
# avg_loss: 14.37141
# EPOCH 69:
# avg_loss: 14.31074
# EPOCH 70:
# avg_loss: 14.24455
# EPOCH 71:
# avg_loss: 14.18022
# EPOCH 72:
# avg_loss: 14.13328
# EPOCH 73:
# avg_loss: 14.06693
# EPOCH 74:
# avg_loss: 14.04491
# EPOCH 75:
# avg_loss: 14.00597
# EPOCH 76:
# avg_loss: 13.97775
# EPOCH 77:
# avg_loss: 13.94903
# EPOCH 78:
# avg_loss: 13.92742
# EPOCH 79:
# avg_loss: 13.90670
# EPOCH 80:
# avg_loss: 13.90434
# EPOCH 81:
# avg_loss: 13.88687
# EPOCH 82:
# avg_loss: 13.87800
# EPOCH 83:
# avg_loss: 13.86302
# EPOCH 84:
# avg_loss: 13.84605
# EPOCH 85:
# avg_loss: 13.81837
# EPOCH 86:
# avg_loss: 13.81022
# EPOCH 87:
# avg_loss: 13.79361
# EPOCH 88:
# avg_loss: 13.78342
# EPOCH 89:
# avg_loss: 13.77615
# EPOCH 90:
# avg_loss: 13.78445
# EPOCH 91:
# avg_loss: 13.76442
# EPOCH 92:
# avg_loss: 13.77098
# EPOCH 93:
# avg_loss: 13.77389
# EPOCH 94:
# avg_loss: 13.77266
# EPOCH 95:
# avg_loss: 13.76895
# EPOCH 96:
# avg_loss: 13.77548
# EPOCH 97:
# avg_loss: 13.77444
# EPOCH 98:
# avg_loss: 13.76311
# EPOCH 99:
# avg_loss: 13.76226
# EPOCH 100:
# avg_loss: 13.76136
# Execution time: 62.923541 seconds
# baseline average loss:  0.1617654608039374
# baseline repeat:  0.2056179820988955
# regression loss total:  0.13675641644828448
# model loss total:  0.12617051601409912
#
# regression loss predindex:  0.19126467908143852
# model loss predindex:  0.15282732248306274
# Train size:  794
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss: 20.69698
# EPOCH 2:
# avg_loss: 16.97714
# EPOCH 3:
# avg_loss: 16.38763
# EPOCH 4:
# avg_loss: 16.06738
# EPOCH 5:
# avg_loss: 15.87309
# EPOCH 6:
# avg_loss: 15.74837
# EPOCH 7:
# avg_loss: 15.66472
# EPOCH 8:
# avg_loss: 15.61857
# EPOCH 9:
# avg_loss: 15.57813
# EPOCH 10:
# avg_loss: 15.54602
# EPOCH 11:
# avg_loss: 15.49162
# EPOCH 12:
# avg_loss: 15.39892
# EPOCH 13:
# avg_loss: 15.26063
# EPOCH 14:
# avg_loss: 15.16413
# EPOCH 15:
# avg_loss: 15.09195
# EPOCH 16:
# avg_loss: 15.06369
# EPOCH 17:
# avg_loss: 15.02918
# EPOCH 18:
# avg_loss: 14.99592
# EPOCH 19:
# avg_loss: 14.95175
# EPOCH 20:
# avg_loss: 14.90915
# EPOCH 21:
# avg_loss: 14.85962
# EPOCH 22:
# avg_loss: 14.79383
# EPOCH 23:
# avg_loss: 14.74670
# EPOCH 24:
# avg_loss: 14.72149
# EPOCH 25:
# avg_loss: 14.69233
# EPOCH 26:
# avg_loss: 14.67534
# EPOCH 27:
# avg_loss: 14.64685
# EPOCH 28:
# avg_loss: 14.61982
# EPOCH 29:
# avg_loss: 14.59853
# EPOCH 30:
# avg_loss: 14.58149
# EPOCH 31:
# avg_loss: 14.58293
# EPOCH 32:
# avg_loss: 14.57347
# EPOCH 33:
# avg_loss: 14.56445
# EPOCH 34:
# avg_loss: 14.55261
# EPOCH 35:
# avg_loss: 14.54625
# EPOCH 36:
# avg_loss: 14.54269
# EPOCH 37:
# avg_loss: 14.52438
# EPOCH 38:
# avg_loss: 14.49545
# EPOCH 39:
# avg_loss: 14.46716
# EPOCH 40:
# avg_loss: 14.43773
# EPOCH 41:
# avg_loss: 14.40964
# EPOCH 42:
# avg_loss: 14.40474
# EPOCH 43:
# avg_loss: 14.39638
# EPOCH 44:
# avg_loss: 14.39044
# EPOCH 45:
# avg_loss: 14.39130
# EPOCH 46:
# avg_loss: 14.38228
# EPOCH 47:
# avg_loss: 14.37797
# EPOCH 48:
# avg_loss: 14.37181
# EPOCH 49:
# avg_loss: 14.36449
# EPOCH 50:
# avg_loss: 14.36158
# EPOCH 51:
# avg_loss: 14.36241
# EPOCH 52:
# avg_loss: 14.35327
# EPOCH 53:
# avg_loss: 14.36078
# EPOCH 54:
# avg_loss: 14.35353
# EPOCH 55:
# avg_loss: 14.34758
# EPOCH 56:
# avg_loss: 14.34753
# EPOCH 57:
# avg_loss: 14.33770
# EPOCH 58:
# avg_loss: 14.34193
# EPOCH 59:
# avg_loss: 14.32455
# EPOCH 60:
# avg_loss: 14.32535
# EPOCH 61:
# avg_loss: 14.31228
# EPOCH 62:
# avg_loss: 14.29756
# EPOCH 63:
# avg_loss: 14.29882
# EPOCH 64:
# avg_loss: 14.30704
# EPOCH 65:
# avg_loss: 14.29023
# EPOCH 66:
# avg_loss: 14.29012
# EPOCH 67:
# avg_loss: 14.28611
# EPOCH 68:
# avg_loss: 14.28043
# EPOCH 69:
# avg_loss: 14.27610
# EPOCH 70:
# avg_loss: 14.27365
# EPOCH 71:
# avg_loss: 14.27095
# EPOCH 72:
# avg_loss: 14.26460
# EPOCH 73:
# avg_loss: 14.25848
# EPOCH 74:
# avg_loss: 14.24656
# EPOCH 75:
# avg_loss: 14.23258
# EPOCH 76:
# avg_loss: 14.18835
# EPOCH 77:
# avg_loss: 14.11803
# EPOCH 78:
# avg_loss: 14.06430
# EPOCH 79:
# avg_loss: 13.99972
# EPOCH 80:
# avg_loss: 13.92940
# EPOCH 81:
# avg_loss: 13.86037
# EPOCH 82:
# avg_loss: 13.80342
# EPOCH 83:
# avg_loss: 13.76290
# EPOCH 84:
# avg_loss: 13.71650
# EPOCH 85:
# avg_loss: 13.68462
# EPOCH 86:
# avg_loss: 13.66798
# EPOCH 87:
# avg_loss: 13.65193
# EPOCH 88:
# avg_loss: 13.63935
# EPOCH 89:
# avg_loss: 13.63772
# EPOCH 90:
# avg_loss: 13.62696
# EPOCH 91:
# avg_loss: 13.62729
# EPOCH 92:
# avg_loss: 13.62723
# EPOCH 93:
# avg_loss: 13.62280
# EPOCH 94:
# avg_loss: 13.62234
# EPOCH 95:
# avg_loss: 13.62685
# EPOCH 96:
# avg_loss: 13.62927
# EPOCH 97:
# avg_loss: 13.61637
# EPOCH 98:
# avg_loss: 13.62007
# EPOCH 99:
# avg_loss: 13.61348
# EPOCH 100:
# avg_loss: 13.61394
# Execution time: 63.044754 seconds
# baseline average loss:  0.1766165124929764
# baseline repeat:  0.22500000487674365
# regression loss total:  0.15648478365936147
# model loss total:  0.1489713340997696
#
# regression loss predindex:  0.20931678525470698
# model loss predindex:  0.18457919359207153
# Train size:  794
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss: 20.76801
# EPOCH 2:
# avg_loss: 17.03289
# EPOCH 3:
# avg_loss: 16.45516
# EPOCH 4:
# avg_loss: 16.11854
# EPOCH 5:
# avg_loss: 15.91609
# EPOCH 6:
# avg_loss: 15.78375
# EPOCH 7:
# avg_loss: 15.69940
# EPOCH 8:
# avg_loss: 15.65383
# EPOCH 9:
# avg_loss: 15.61214
# EPOCH 10:
# avg_loss: 15.59293
# EPOCH 11:
# avg_loss: 15.53662
# EPOCH 12:
# avg_loss: 15.46118
# EPOCH 13:
# avg_loss: 15.34908
# EPOCH 14:
# avg_loss: 15.21622
# EPOCH 15:
# avg_loss: 15.13603
# EPOCH 16:
# avg_loss: 15.09137
# EPOCH 17:
# avg_loss: 15.05184
# EPOCH 18:
# avg_loss: 15.01146
# EPOCH 19:
# avg_loss: 14.97706
# EPOCH 20:
# avg_loss: 14.93446
# EPOCH 21:
# avg_loss: 14.86342
# EPOCH 22:
# avg_loss: 14.80641
# EPOCH 23:
# avg_loss: 14.74797
# EPOCH 24:
# avg_loss: 14.70614
# EPOCH 25:
# avg_loss: 14.65959
# EPOCH 26:
# avg_loss: 14.62970
# EPOCH 27:
# avg_loss: 14.61177
# EPOCH 28:
# avg_loss: 14.58866
# EPOCH 29:
# avg_loss: 14.58683
# EPOCH 30:
# avg_loss: 14.56988
# EPOCH 31:
# avg_loss: 14.57351
# EPOCH 32:
# avg_loss: 14.57055
# EPOCH 33:
# avg_loss: 14.56412
# EPOCH 34:
# avg_loss: 14.55846
# EPOCH 35:
# avg_loss: 14.55078
# EPOCH 36:
# avg_loss: 14.54739
# EPOCH 37:
# avg_loss: 14.54633
# EPOCH 38:
# avg_loss: 14.55061
# EPOCH 39:
# avg_loss: 14.53870
# EPOCH 40:
# avg_loss: 14.53604
# EPOCH 41:
# avg_loss: 14.53496
# EPOCH 42:
# avg_loss: 14.53075
# EPOCH 43:
# avg_loss: 14.53115
# EPOCH 44:
# avg_loss: 14.52797
# EPOCH 45:
# avg_loss: 14.53313
# EPOCH 46:
# avg_loss: 14.51816
# EPOCH 47:
# avg_loss: 14.50594
# EPOCH 48:
# avg_loss: 14.50396
# EPOCH 49:
# avg_loss: 14.49483
# EPOCH 50:
# avg_loss: 14.49076
# EPOCH 51:
# avg_loss: 14.47886
# EPOCH 52:
# avg_loss: 14.46604
# EPOCH 53:
# avg_loss: 14.44299
# EPOCH 54:
# avg_loss: 14.42453
# EPOCH 55:
# avg_loss: 14.41376
# EPOCH 56:
# avg_loss: 14.39644
# EPOCH 57:
# avg_loss: 14.37446
# EPOCH 58:
# avg_loss: 14.35628
# EPOCH 59:
# avg_loss: 14.33596
# EPOCH 60:
# avg_loss: 14.32177
# EPOCH 61:
# avg_loss: 14.28166
# EPOCH 62:
# avg_loss: 14.20576
# EPOCH 63:
# avg_loss: 14.13303
# EPOCH 64:
# avg_loss: 14.06756
# EPOCH 65:
# avg_loss: 13.98363
# EPOCH 66:
# avg_loss: 13.92297
# EPOCH 67:
# avg_loss: 13.86392
# EPOCH 68:
# avg_loss: 13.81998
# EPOCH 69:
# avg_loss: 13.78597
# EPOCH 70:
# avg_loss: 13.74585
# EPOCH 71:
# avg_loss: 13.71903
# EPOCH 72:
# avg_loss: 13.70930
# EPOCH 73:
# avg_loss: 13.68333
# EPOCH 74:
# avg_loss: 13.67729
# EPOCH 75:
# avg_loss: 13.67512
# EPOCH 76:
# avg_loss: 13.66196
# EPOCH 77:
# avg_loss: 13.65684
# EPOCH 78:
# avg_loss: 13.64274
# EPOCH 79:
# avg_loss: 13.63665
# EPOCH 80:
# avg_loss: 13.63661
# EPOCH 81:
# avg_loss: 13.62835
# EPOCH 82:
# avg_loss: 13.62356
# EPOCH 83:
# avg_loss: 13.63046
# EPOCH 84:
# avg_loss: 13.62517
# EPOCH 85:
# avg_loss: 13.61275
# EPOCH 86:
# avg_loss: 13.62042
# EPOCH 87:
# avg_loss: 13.61184
# EPOCH 88:
# avg_loss: 13.60254
# EPOCH 89:
# avg_loss: 13.60058
# EPOCH 90:
# avg_loss: 13.60019
# EPOCH 91:
# avg_loss: 13.60091
# EPOCH 92:
# avg_loss: 13.59158
# EPOCH 93:
# avg_loss: 13.58298
# EPOCH 94:
# avg_loss: 13.57295
# EPOCH 95:
# avg_loss: 13.56583
# EPOCH 96:
# avg_loss: 13.54590
# EPOCH 97:
# avg_loss: 13.52547
# EPOCH 98:
# avg_loss: 13.52801
# EPOCH 99:
# avg_loss: 13.50970
# EPOCH 100:
# avg_loss: 13.51059
# Execution time: 63.098481 seconds
# baseline average loss:  0.17176377087492833
# baseline repeat:  0.21136364069851962
# regression loss total:  0.14207141588473257
# model loss total:  0.14059920608997345
#
# regression loss predindex:  0.17358178278929806
# model loss predindex:  0.17030012607574463
# Train size:  794
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss: 20.80824
# EPOCH 2:
# avg_loss: 17.10094
# EPOCH 3:
# avg_loss: 16.52868
# EPOCH 4:
# avg_loss: 16.18242
# EPOCH 5:
# avg_loss: 15.99724
# EPOCH 6:
# avg_loss: 15.86013
# EPOCH 7:
# avg_loss: 15.78044
# EPOCH 8:
# avg_loss: 15.72869
# EPOCH 9:
# avg_loss: 15.68044
# EPOCH 10:
# avg_loss: 15.65492
# EPOCH 11:
# avg_loss: 15.58527
# EPOCH 12:
# avg_loss: 15.48755
# EPOCH 13:
# avg_loss: 15.33445
# EPOCH 14:
# avg_loss: 15.24012
# EPOCH 15:
# avg_loss: 15.19041
# EPOCH 16:
# avg_loss: 15.13415
# EPOCH 17:
# avg_loss: 15.08638
# EPOCH 18:
# avg_loss: 15.03189
# EPOCH 19:
# avg_loss: 14.97912
# EPOCH 20:
# avg_loss: 14.91491
# EPOCH 21:
# avg_loss: 14.85502
# EPOCH 22:
# avg_loss: 14.80800
# EPOCH 23:
# avg_loss: 14.79080
# EPOCH 24:
# avg_loss: 14.75320
# EPOCH 25:
# avg_loss: 14.73562
# EPOCH 26:
# avg_loss: 14.70633
# EPOCH 27:
# avg_loss: 14.68269
# EPOCH 28:
# avg_loss: 14.66674
# EPOCH 29:
# avg_loss: 14.65399
# EPOCH 30:
# avg_loss: 14.64566
# EPOCH 31:
# avg_loss: 14.63934
# EPOCH 32:
# avg_loss: 14.63793
# EPOCH 33:
# avg_loss: 14.63501
# EPOCH 34:
# avg_loss: 14.62721
# EPOCH 35:
# avg_loss: 14.61637
# EPOCH 36:
# avg_loss: 14.61388
# EPOCH 37:
# avg_loss: 14.60747
# EPOCH 38:
# avg_loss: 14.60055
# EPOCH 39:
# avg_loss: 14.59639
# EPOCH 40:
# avg_loss: 14.59131
# EPOCH 41:
# avg_loss: 14.59024
# EPOCH 42:
# avg_loss: 14.56851
# EPOCH 43:
# avg_loss: 14.56053
# EPOCH 44:
# avg_loss: 14.54425
# EPOCH 45:
# avg_loss: 14.52444
# EPOCH 46:
# avg_loss: 14.49978
# EPOCH 47:
# avg_loss: 14.48643
# EPOCH 48:
# avg_loss: 14.47201
# EPOCH 49:
# avg_loss: 14.45346
# EPOCH 50:
# avg_loss: 14.44926
# EPOCH 51:
# avg_loss: 14.45452
# EPOCH 52:
# avg_loss: 14.45401
# EPOCH 53:
# avg_loss: 14.44199
# EPOCH 54:
# avg_loss: 14.44999
# EPOCH 55:
# avg_loss: 14.44189
# EPOCH 56:
# avg_loss: 14.43785
# EPOCH 57:
# avg_loss: 14.43707
# EPOCH 58:
# avg_loss: 14.44022
# EPOCH 59:
# avg_loss: 14.42794
# EPOCH 60:
# avg_loss: 14.43189
# EPOCH 61:
# avg_loss: 14.42614
# EPOCH 62:
# avg_loss: 14.42733
# EPOCH 63:
# avg_loss: 14.41459
# EPOCH 64:
# avg_loss: 14.41740
# EPOCH 65:
# avg_loss: 14.41344
# EPOCH 66:
# avg_loss: 14.41192
# EPOCH 67:
# avg_loss: 14.39116
# EPOCH 68:
# avg_loss: 14.39317
# EPOCH 69:
# avg_loss: 14.38757
# EPOCH 70:
# avg_loss: 14.37798
# EPOCH 71:
# avg_loss: 14.37280
# EPOCH 72:
# avg_loss: 14.36601
# EPOCH 73:
# avg_loss: 14.36454
# EPOCH 74:
# avg_loss: 14.36231
# EPOCH 75:
# avg_loss: 14.36196
# EPOCH 76:
# avg_loss: 14.36194
# EPOCH 77:
# avg_loss: 14.35758
# EPOCH 78:
# avg_loss: 14.35465
# EPOCH 79:
# avg_loss: 14.34905
# EPOCH 80:
# avg_loss: 14.34864
# EPOCH 81:
# avg_loss: 14.35216
# EPOCH 82:
# avg_loss: 14.34026
# EPOCH 83:
# avg_loss: 14.34696
# EPOCH 84:
# avg_loss: 14.32337
# EPOCH 85:
# avg_loss: 14.28589
# EPOCH 86:
# avg_loss: 14.22984
# EPOCH 87:
# avg_loss: 14.17215
# EPOCH 88:
# avg_loss: 14.11772
# EPOCH 89:
# avg_loss: 14.05934
# EPOCH 90:
# avg_loss: 14.00688
# EPOCH 91:
# avg_loss: 13.96138
# EPOCH 92:
# avg_loss: 13.92096
# EPOCH 93:
# avg_loss: 13.88727
# EPOCH 94:
# avg_loss: 13.85460
# EPOCH 95:
# avg_loss: 13.82453
# EPOCH 96:
# avg_loss: 13.80346
# EPOCH 97:
# avg_loss: 13.78716
# EPOCH 98:
# avg_loss: 13.78156
# EPOCH 99:
# avg_loss: 13.76947
# EPOCH 100:
# avg_loss: 13.76274
# Execution time: 63.285975 seconds
# baseline average loss:  0.1804892886430025
# baseline repeat:  0.24090909636156124
# regression loss total:  0.15859150137877992
# model loss total:  0.1545797884464264
#
# regression loss predindex:  0.208917470528829
# model loss predindex:  0.1984766125679016
# Train size:  794
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss: 21.05799
# EPOCH 2:
# avg_loss: 17.25446
# EPOCH 3:
# avg_loss: 16.66813
# EPOCH 4:
# avg_loss: 16.35159
# EPOCH 5:
# avg_loss: 16.15262
# EPOCH 6:
# avg_loss: 16.03056
# EPOCH 7:
# avg_loss: 15.94333
# EPOCH 8:
# avg_loss: 15.89277
# EPOCH 9:
# avg_loss: 15.85229
# EPOCH 10:
# avg_loss: 15.80217
# EPOCH 11:
# avg_loss: 15.74101
# EPOCH 12:
# avg_loss: 15.65603
# EPOCH 13:
# avg_loss: 15.52942
# EPOCH 14:
# avg_loss: 15.39754
# EPOCH 15:
# avg_loss: 15.31413
# EPOCH 16:
# avg_loss: 15.26721
# EPOCH 17:
# avg_loss: 15.22275
# EPOCH 18:
# avg_loss: 15.17348
# EPOCH 19:
# avg_loss: 15.09951
# EPOCH 20:
# avg_loss: 15.03702
# EPOCH 21:
# avg_loss: 14.97352
# EPOCH 22:
# avg_loss: 14.93499
# EPOCH 23:
# avg_loss: 14.90994
# EPOCH 24:
# avg_loss: 14.86527
# EPOCH 25:
# avg_loss: 14.84039
# EPOCH 26:
# avg_loss: 14.80906
# EPOCH 27:
# avg_loss: 14.80199
# EPOCH 28:
# avg_loss: 14.77596
# EPOCH 29:
# avg_loss: 14.77383
# EPOCH 30:
# avg_loss: 14.77799
# EPOCH 31:
# avg_loss: 14.76229
# EPOCH 32:
# avg_loss: 14.76279
# EPOCH 33:
# avg_loss: 14.75792
# EPOCH 34:
# avg_loss: 14.75468
# EPOCH 35:
# avg_loss: 14.73877
# EPOCH 36:
# avg_loss: 14.73454
# EPOCH 37:
# avg_loss: 14.72456
# EPOCH 38:
# avg_loss: 14.71521
# EPOCH 39:
# avg_loss: 14.70575
# EPOCH 40:
# avg_loss: 14.69172
# EPOCH 41:
# avg_loss: 14.66973
# EPOCH 42:
# avg_loss: 14.65288
# EPOCH 43:
# avg_loss: 14.63716
# EPOCH 44:
# avg_loss: 14.63188
# EPOCH 45:
# avg_loss: 14.62424
# EPOCH 46:
# avg_loss: 14.62332
# EPOCH 47:
# avg_loss: 14.61589
# EPOCH 48:
# avg_loss: 14.61118
# EPOCH 49:
# avg_loss: 14.61292
# EPOCH 50:
# avg_loss: 14.60871
# EPOCH 51:
# avg_loss: 14.60356
# EPOCH 52:
# avg_loss: 14.60069
# EPOCH 53:
# avg_loss: 14.60028
# EPOCH 54:
# avg_loss: 14.60179
# EPOCH 55:
# avg_loss: 14.60399
# EPOCH 56:
# avg_loss: 14.59960
# EPOCH 57:
# avg_loss: 14.59086
# EPOCH 58:
# avg_loss: 14.58912
# EPOCH 59:
# avg_loss: 14.59611
# EPOCH 60:
# avg_loss: 14.59553
# EPOCH 61:
# avg_loss: 14.59361
# EPOCH 62:
# avg_loss: 14.58656
# EPOCH 63:
# avg_loss: 14.58581
# EPOCH 64:
# avg_loss: 14.58170
# EPOCH 65:
# avg_loss: 14.59091
# EPOCH 66:
# avg_loss: 14.58800
# EPOCH 67:
# avg_loss: 14.59408
# EPOCH 68:
# avg_loss: 14.58489
# EPOCH 69:
# avg_loss: 14.58620
# EPOCH 70:
# avg_loss: 14.58822
# EPOCH 71:
# avg_loss: 14.58643
# EPOCH 72:
# avg_loss: 14.58608
# EPOCH 73:
# avg_loss: 14.58018
# EPOCH 74:
# avg_loss: 14.57434
# EPOCH 75:
# avg_loss: 14.56065
# EPOCH 76:
# avg_loss: 14.57141
# EPOCH 77:
# avg_loss: 14.56275
# EPOCH 78:
# avg_loss: 14.56245
# EPOCH 79:
# avg_loss: 14.55944
# EPOCH 80:
# avg_loss: 14.55272
# EPOCH 81:
# avg_loss: 14.54634
# EPOCH 82:
# avg_loss: 14.53086
# EPOCH 83:
# avg_loss: 14.52203
# EPOCH 84:
# avg_loss: 14.51308
# EPOCH 85:
# avg_loss: 14.51576
# EPOCH 86:
# avg_loss: 14.51397
# EPOCH 87:
# avg_loss: 14.51140
# EPOCH 88:
# avg_loss: 14.50178
# EPOCH 89:
# avg_loss: 14.50440
# EPOCH 90:
# avg_loss: 14.49970
# EPOCH 91:
# avg_loss: 14.49606
# EPOCH 92:
# avg_loss: 14.49085
# EPOCH 93:
# avg_loss: 14.49147
# EPOCH 94:
# avg_loss: 14.49225
# EPOCH 95:
# avg_loss: 14.49349
# EPOCH 96:
# avg_loss: 14.48661
# EPOCH 97:
# avg_loss: 14.47339
# EPOCH 98:
# avg_loss: 14.47615
# EPOCH 99:
# avg_loss: 14.44500
# EPOCH 100:
# avg_loss: 14.38765
# Execution time: 61.972494 seconds
# baseline average loss:  0.17231527047062462
# baseline repeat:  0.21818182346495715
# regression loss total:  0.14888265560809483
# model loss total:  0.15330244600772858
#
# regression loss predindex:  0.22769751422278375
# model loss predindex:  0.22529155015945435
# Train size:  794
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss: 20.93475
# EPOCH 2:
# avg_loss: 17.14146
# EPOCH 3:
# avg_loss: 16.56616
# EPOCH 4:
# avg_loss: 16.24224
# EPOCH 5:
# avg_loss: 16.04606
# EPOCH 6:
# avg_loss: 15.91822
# EPOCH 7:
# avg_loss: 15.82788
# EPOCH 8:
# avg_loss: 15.78203
# EPOCH 9:
# avg_loss: 15.73642
# EPOCH 10:
# avg_loss: 15.71356
# EPOCH 11:
# avg_loss: 15.65845
# EPOCH 12:
# avg_loss: 15.56530
# EPOCH 13:
# avg_loss: 15.44408
# EPOCH 14:
# avg_loss: 15.32081
# EPOCH 15:
# avg_loss: 15.25023
# EPOCH 16:
# avg_loss: 15.20112
# EPOCH 17:
# avg_loss: 15.16312
# EPOCH 18:
# avg_loss: 15.12956
# EPOCH 19:
# avg_loss: 15.09717
# EPOCH 20:
# avg_loss: 15.04041
# EPOCH 21:
# avg_loss: 14.97460
# EPOCH 22:
# avg_loss: 14.91905
# EPOCH 23:
# avg_loss: 14.87428
# EPOCH 24:
# avg_loss: 14.84376
# EPOCH 25:
# avg_loss: 14.82390
# EPOCH 26:
# avg_loss: 14.79042
# EPOCH 27:
# avg_loss: 14.76469
# EPOCH 28:
# avg_loss: 14.73432
# EPOCH 29:
# avg_loss: 14.72010
# EPOCH 30:
# avg_loss: 14.71055
# EPOCH 31:
# avg_loss: 14.70273
# EPOCH 32:
# avg_loss: 14.68439
# EPOCH 33:
# avg_loss: 14.68718
# EPOCH 34:
# avg_loss: 14.67934
# EPOCH 35:
# avg_loss: 14.67997
# EPOCH 36:
# avg_loss: 14.67081
# EPOCH 37:
# avg_loss: 14.66184
# EPOCH 38:
# avg_loss: 14.65590
# EPOCH 39:
# avg_loss: 14.64455
# EPOCH 40:
# avg_loss: 14.64054
# EPOCH 41:
# avg_loss: 14.61721
# EPOCH 42:
# avg_loss: 14.60385
# EPOCH 43:
# avg_loss: 14.56084
# EPOCH 44:
# avg_loss: 14.54170
# EPOCH 45:
# avg_loss: 14.52693
# EPOCH 46:
# avg_loss: 14.51940
# EPOCH 47:
# avg_loss: 14.50800
# EPOCH 48:
# avg_loss: 14.49954
# EPOCH 49:
# avg_loss: 14.50201
# EPOCH 50:
# avg_loss: 14.50400
# EPOCH 51:
# avg_loss: 14.50218
# EPOCH 52:
# avg_loss: 14.49595
# EPOCH 53:
# avg_loss: 14.49915
# EPOCH 54:
# avg_loss: 14.49220
# EPOCH 55:
# avg_loss: 14.49439
# EPOCH 56:
# avg_loss: 14.48652
# EPOCH 57:
# avg_loss: 14.48965
# EPOCH 58:
# avg_loss: 14.48643
# EPOCH 59:
# avg_loss: 14.48786
# EPOCH 60:
# avg_loss: 14.48084
# EPOCH 61:
# avg_loss: 14.47615
# EPOCH 62:
# avg_loss: 14.47045
# EPOCH 63:
# avg_loss: 14.46986
# EPOCH 64:
# avg_loss: 14.46286
# EPOCH 65:
# avg_loss: 14.45677
# EPOCH 66:
# avg_loss: 14.45207
# EPOCH 67:
# avg_loss: 14.44512
# EPOCH 68:
# avg_loss: 14.42942
# EPOCH 69:
# avg_loss: 14.42729
# EPOCH 70:
# avg_loss: 14.38529
# EPOCH 71:
# avg_loss: 14.32163
# EPOCH 72:
# avg_loss: 14.21947
# EPOCH 73:
# avg_loss: 14.13404
# EPOCH 74:
# avg_loss: 14.06475
# EPOCH 75:
# avg_loss: 13.98395
# EPOCH 76:
# avg_loss: 13.93391
# EPOCH 77:
# avg_loss: 13.88006
# EPOCH 78:
# avg_loss: 13.84270
# EPOCH 79:
# avg_loss: 13.80483
# EPOCH 80:
# avg_loss: 13.79149
# EPOCH 81:
# avg_loss: 13.76328
# EPOCH 82:
# avg_loss: 13.75469
# EPOCH 83:
# avg_loss: 13.75114
# EPOCH 84:
# avg_loss: 13.74224
# EPOCH 85:
# avg_loss: 13.74626
# EPOCH 86:
# avg_loss: 13.74088
# EPOCH 87:
# avg_loss: 13.73731
# EPOCH 88:
# avg_loss: 13.73987
# EPOCH 89:
# avg_loss: 13.73987
# EPOCH 90:
# avg_loss: 13.72946
# EPOCH 91:
# avg_loss: 13.73064
# EPOCH 92:
# avg_loss: 13.72735
# EPOCH 93:
# avg_loss: 13.73213
# EPOCH 94:
# avg_loss: 13.72687
# EPOCH 95:
# avg_loss: 13.73042
# EPOCH 96:
# avg_loss: 13.72789
# EPOCH 97:
# avg_loss: 13.72627
# EPOCH 98:
# avg_loss: 13.71906
# EPOCH 99:
# avg_loss: 13.72409
# EPOCH 100:
# avg_loss: 13.72984
# Execution time: 63.310020 seconds
# baseline average loss:  0.1686594525182789
# baseline repeat:  0.2272727321833372
# regression loss total:  0.14820633147980916
# model loss total:  0.13660208880901337
#
# regression loss predindex:  0.23772033482742475
# model loss predindex:  0.22268962860107422
# Train size:  794
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss: 20.88438
# EPOCH 2:
# avg_loss: 17.07722
# EPOCH 3:
# avg_loss: 16.48458
# EPOCH 4:
# avg_loss: 16.15460
# EPOCH 5:
# avg_loss: 15.97087
# EPOCH 6:
# avg_loss: 15.84017
# EPOCH 7:
# avg_loss: 15.75243
# EPOCH 8:
# avg_loss: 15.70281
# EPOCH 9:
# avg_loss: 15.66494
# EPOCH 10:
# avg_loss: 15.62019
# EPOCH 11:
# avg_loss: 15.52792
# EPOCH 12:
# avg_loss: 15.38970
# EPOCH 13:
# avg_loss: 15.27143
# EPOCH 14:
# avg_loss: 15.18190
# EPOCH 15:
# avg_loss: 15.13029
# EPOCH 16:
# avg_loss: 15.08984
# EPOCH 17:
# avg_loss: 15.04745
# EPOCH 18:
# avg_loss: 15.00998
# EPOCH 19:
# avg_loss: 14.95352
# EPOCH 20:
# avg_loss: 14.89578
# EPOCH 21:
# avg_loss: 14.83822
# EPOCH 22:
# avg_loss: 14.79832
# EPOCH 23:
# avg_loss: 14.77486
# EPOCH 24:
# avg_loss: 14.75372
# EPOCH 25:
# avg_loss: 14.72814
# EPOCH 26:
# avg_loss: 14.69566
# EPOCH 27:
# avg_loss: 14.66405
# EPOCH 28:
# avg_loss: 14.63150
# EPOCH 29:
# avg_loss: 14.60859
# EPOCH 30:
# avg_loss: 14.59586
# EPOCH 31:
# avg_loss: 14.59074
# EPOCH 32:
# avg_loss: 14.57290
# EPOCH 33:
# avg_loss: 14.57847
# EPOCH 34:
# avg_loss: 14.55752
# EPOCH 35:
# avg_loss: 14.55509
# EPOCH 36:
# avg_loss: 14.55711
# EPOCH 37:
# avg_loss: 14.55248
# EPOCH 38:
# avg_loss: 14.55192
# EPOCH 39:
# avg_loss: 14.54673
# EPOCH 40:
# avg_loss: 14.52123
# EPOCH 41:
# avg_loss: 14.53037
# EPOCH 42:
# avg_loss: 14.51580
# EPOCH 43:
# avg_loss: 14.50093
# EPOCH 44:
# avg_loss: 14.49916
# EPOCH 45:
# avg_loss: 14.46798
# EPOCH 46:
# avg_loss: 14.44750
# EPOCH 47:
# avg_loss: 14.42382
# EPOCH 48:
# avg_loss: 14.41361
# EPOCH 49:
# avg_loss: 14.40381
# EPOCH 50:
# avg_loss: 14.38541
# EPOCH 51:
# avg_loss: 14.38522
# EPOCH 52:
# avg_loss: 14.35924
# EPOCH 53:
# avg_loss: 14.31548
# EPOCH 54:
# avg_loss: 14.24664
# EPOCH 55:
# avg_loss: 14.17536
# EPOCH 56:
# avg_loss: 14.10028
# EPOCH 57:
# avg_loss: 14.02852
# EPOCH 58:
# avg_loss: 13.95945
# EPOCH 59:
# avg_loss: 13.90864
# EPOCH 60:
# avg_loss: 13.86135
# EPOCH 61:
# avg_loss: 13.81622
# EPOCH 62:
# avg_loss: 13.78938
# EPOCH 63:
# avg_loss: 13.76943
# EPOCH 64:
# avg_loss: 13.74721
# EPOCH 65:
# avg_loss: 13.73496
# EPOCH 66:
# avg_loss: 13.72626
# EPOCH 67:
# avg_loss: 13.73281
# EPOCH 68:
# avg_loss: 13.72085
# EPOCH 69:
# avg_loss: 13.71310
# EPOCH 70:
# avg_loss: 13.71556
# EPOCH 71:
# avg_loss: 13.70910
# EPOCH 72:
# avg_loss: 13.70703
# EPOCH 73:
# avg_loss: 13.70027
# EPOCH 74:
# avg_loss: 13.70278
# EPOCH 75:
# avg_loss: 13.69157
# EPOCH 76:
# avg_loss: 13.68860
# EPOCH 77:
# avg_loss: 13.68682
# EPOCH 78:
# avg_loss: 13.68593
# EPOCH 79:
# avg_loss: 13.68925
# EPOCH 80:
# avg_loss: 13.68045
# EPOCH 81:
# avg_loss: 13.67485
# EPOCH 82:
# avg_loss: 13.66755
# EPOCH 83:
# avg_loss: 13.66472
# EPOCH 84:
# avg_loss: 13.66778
# EPOCH 85:
# avg_loss: 13.66828
# EPOCH 86:
# avg_loss: 13.65690
# EPOCH 87:
# avg_loss: 13.65366
# EPOCH 88:
# avg_loss: 13.64721
# EPOCH 89:
# avg_loss: 13.64423
# EPOCH 90:
# avg_loss: 13.62841
# EPOCH 91:
# avg_loss: 13.61288
# EPOCH 92:
# avg_loss: 13.61328
# EPOCH 93:
# avg_loss: 13.58505
# EPOCH 94:
# avg_loss: 13.56362
# EPOCH 95:
# avg_loss: 13.55995
# EPOCH 96:
# avg_loss: 13.53918
# EPOCH 97:
# avg_loss: 13.53743
# EPOCH 98:
# avg_loss: 13.53723
# EPOCH 99:
# avg_loss: 13.53265
# EPOCH 100:
# avg_loss: 13.53214
# Execution time: 63.080761 seconds
# baseline average loss:  0.1577098113908009
# baseline repeat:  0.20340909605676477
# regression loss total:  0.1343367611747317
# model loss total:  0.1273128241300583
#
# regression loss predindex:  0.18384321115064015
# model loss predindex:  0.1819770336151123
# Train size:  794
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss: 20.71814
# EPOCH 2:
# avg_loss: 17.06614
# EPOCH 3:
# avg_loss: 16.47545
# EPOCH 4:
# avg_loss: 16.13080
# EPOCH 5:
# avg_loss: 15.92601
# EPOCH 6:
# avg_loss: 15.78363
# EPOCH 7:
# avg_loss: 15.70874
# EPOCH 8:
# avg_loss: 15.65771
# EPOCH 9:
# avg_loss: 15.62639
# EPOCH 10:
# avg_loss: 15.59551
# EPOCH 11:
# avg_loss: 15.55175
# EPOCH 12:
# avg_loss: 15.47906
# EPOCH 13:
# avg_loss: 15.36552
# EPOCH 14:
# avg_loss: 15.25111
# EPOCH 15:
# avg_loss: 15.16043
# EPOCH 16:
# avg_loss: 15.11543
# EPOCH 17:
# avg_loss: 15.06818
# EPOCH 18:
# avg_loss: 15.01964
# EPOCH 19:
# avg_loss: 14.96992
# EPOCH 20:
# avg_loss: 14.90791
# EPOCH 21:
# avg_loss: 14.82817
# EPOCH 22:
# avg_loss: 14.77945
# EPOCH 23:
# avg_loss: 14.75194
# EPOCH 24:
# avg_loss: 14.72030
# EPOCH 25:
# avg_loss: 14.68384
# EPOCH 26:
# avg_loss: 14.65435
# EPOCH 27:
# avg_loss: 14.62258
# EPOCH 28:
# avg_loss: 14.61765
# EPOCH 29:
# avg_loss: 14.60200
# EPOCH 30:
# avg_loss: 14.59943
# EPOCH 31:
# avg_loss: 14.59033
# EPOCH 32:
# avg_loss: 14.59207
# EPOCH 33:
# avg_loss: 14.57836
# EPOCH 34:
# avg_loss: 14.57823
# EPOCH 35:
# avg_loss: 14.57202
# EPOCH 36:
# avg_loss: 14.56309
# EPOCH 37:
# avg_loss: 14.55185
# EPOCH 38:
# avg_loss: 14.54727
# EPOCH 39:
# avg_loss: 14.54501
# EPOCH 40:
# avg_loss: 14.54195
# EPOCH 41:
# avg_loss: 14.52851
# EPOCH 42:
# avg_loss: 14.51268
# EPOCH 43:
# avg_loss: 14.50249
# EPOCH 44:
# avg_loss: 14.48962
# EPOCH 45:
# avg_loss: 14.47077
# EPOCH 46:
# avg_loss: 14.46168
# EPOCH 47:
# avg_loss: 14.44852
# EPOCH 48:
# avg_loss: 14.42464
# EPOCH 49:
# avg_loss: 14.42600
# EPOCH 50:
# avg_loss: 14.41882
# EPOCH 51:
# avg_loss: 14.41704
# EPOCH 52:
# avg_loss: 14.40860
# EPOCH 53:
# avg_loss: 14.40613
# EPOCH 54:
# avg_loss: 14.39271
# EPOCH 55:
# avg_loss: 14.39364
# EPOCH 56:
# avg_loss: 14.38493
# EPOCH 57:
# avg_loss: 14.38159
# EPOCH 58:
# avg_loss: 14.36627
# EPOCH 59:
# avg_loss: 14.35708
# EPOCH 60:
# avg_loss: 14.34324
# EPOCH 61:
# avg_loss: 14.33278
# EPOCH 62:
# avg_loss: 14.32099
# EPOCH 63:
# avg_loss: 14.30146
# EPOCH 64:
# avg_loss: 14.26100
# EPOCH 65:
# avg_loss: 14.18678
# EPOCH 66:
# avg_loss: 14.11299
# EPOCH 67:
# avg_loss: 14.03699
# EPOCH 68:
# avg_loss: 13.96064
# EPOCH 69:
# avg_loss: 13.87596
# EPOCH 70:
# avg_loss: 13.81525
# EPOCH 71:
# avg_loss: 13.76746
# EPOCH 72:
# avg_loss: 13.72663
# EPOCH 73:
# avg_loss: 13.69809
# EPOCH 74:
# avg_loss: 13.68033
# EPOCH 75:
# avg_loss: 13.66626
# EPOCH 76:
# avg_loss: 13.64493
# EPOCH 77:
# avg_loss: 13.64745
# EPOCH 78:
# avg_loss: 13.63867
# EPOCH 79:
# avg_loss: 13.63784
# EPOCH 80:
# avg_loss: 13.63415
# EPOCH 81:
# avg_loss: 13.62135
# EPOCH 82:
# avg_loss: 13.62456
# EPOCH 83:
# avg_loss: 13.61795
# EPOCH 84:
# avg_loss: 13.60570
# EPOCH 85:
# avg_loss: 13.60953
# EPOCH 86:
# avg_loss: 13.59746
# EPOCH 87:
# avg_loss: 13.58287
# EPOCH 88:
# avg_loss: 13.56903
# EPOCH 89:
# avg_loss: 13.55372
# EPOCH 90:
# avg_loss: 13.55362
# EPOCH 91:
# avg_loss: 13.54385
# EPOCH 92:
# avg_loss: 13.53716
# EPOCH 93:
# avg_loss: 13.52905
# EPOCH 94:
# avg_loss: 13.53625
# EPOCH 95:
# avg_loss: 13.53580
# EPOCH 96:
# avg_loss: 13.52545
# EPOCH 97:
# avg_loss: 13.52852
# EPOCH 98:
# avg_loss: 13.51858
# EPOCH 99:
# avg_loss: 13.51674
# EPOCH 100:
# avg_loss: 13.51576
# Execution time: 62.333460 seconds
# baseline average loss:  0.1828198597173799
# baseline repeat:  0.23636364124038003
# regression loss total:  0.160098285268087
# model loss total:  0.15156111121177673
#
# regression loss predindex:  0.21080614395468678
# model loss predindex:  0.18410252034664154
# Train size:  794
#
# Val size:  88
#
# Number of Parameters 420
# EPOCH 1:
# avg_loss: 21.24186
# EPOCH 2:
# avg_loss: 17.29074
# EPOCH 3:
# avg_loss: 16.68529
# EPOCH 4:
# avg_loss: 16.33739
# EPOCH 5:
# avg_loss: 16.14309
# EPOCH 6:
# avg_loss: 16.01394
# EPOCH 7:
# avg_loss: 15.93778
# EPOCH 8:
# avg_loss: 15.88324
# EPOCH 9:
# avg_loss: 15.84374
# EPOCH 10:
# avg_loss: 15.79621
# EPOCH 11:
# avg_loss: 15.72230
# EPOCH 12:
# avg_loss: 15.60546
# EPOCH 13:
# avg_loss: 15.46155
# EPOCH 14:
# avg_loss: 15.35007
# EPOCH 15:
# avg_loss: 15.30771
# EPOCH 16:
# avg_loss: 15.27967
# EPOCH 17:
# avg_loss: 15.24922
# EPOCH 18:
# avg_loss: 15.21031
# EPOCH 19:
# avg_loss: 15.16770
# EPOCH 20:
# avg_loss: 15.11433
# EPOCH 21:
# avg_loss: 15.04402
# EPOCH 22:
# avg_loss: 14.98209
# EPOCH 23:
# avg_loss: 14.94367
# EPOCH 24:
# avg_loss: 14.91850
# EPOCH 25:
# avg_loss: 14.89728
# EPOCH 26:
# avg_loss: 14.86976
# EPOCH 27:
# avg_loss: 14.84169
# EPOCH 28:
# avg_loss: 14.82801
# EPOCH 29:
# avg_loss: 14.80403
# EPOCH 30:
# avg_loss: 14.78758
# EPOCH 31:
# avg_loss: 14.78479
# EPOCH 32:
# avg_loss: 14.78086
# EPOCH 33:
# avg_loss: 14.77087
# EPOCH 34:
# avg_loss: 14.76434
# EPOCH 35:
# avg_loss: 14.75937
# EPOCH 36:
# avg_loss: 14.74706
# EPOCH 37:
# avg_loss: 14.72504
# EPOCH 38:
# avg_loss: 14.68550
# EPOCH 39:
# avg_loss: 14.64639
# EPOCH 40:
# avg_loss: 14.62198
# EPOCH 41:
# avg_loss: 14.60607
# EPOCH 42:
# avg_loss: 14.60842
# EPOCH 43:
# avg_loss: 14.59731
# EPOCH 44:
# avg_loss: 14.59253
# EPOCH 45:
# avg_loss: 14.58130
# EPOCH 46:
# avg_loss: 14.59759
# EPOCH 47:
# avg_loss: 14.59019
# EPOCH 48:
# avg_loss: 14.58347
# EPOCH 49:
# avg_loss: 14.57571
# EPOCH 50:
# avg_loss: 14.58071
# EPOCH 51:
# avg_loss: 14.57574
# EPOCH 52:
# avg_loss: 14.57040
# EPOCH 53:
# avg_loss: 14.56845
# EPOCH 54:
# avg_loss: 14.56438
# EPOCH 55:
# avg_loss: 14.56501
# EPOCH 56:
# avg_loss: 14.56505
# EPOCH 57:
# avg_loss: 14.55946
# EPOCH 58:
# avg_loss: 14.55272
# EPOCH 59:
# avg_loss: 14.54881
# EPOCH 60:
# avg_loss: 14.54435
# EPOCH 61:
# avg_loss: 14.53778
# EPOCH 62:
# avg_loss: 14.52480
# EPOCH 63:
# avg_loss: 14.52446
# EPOCH 64:
# avg_loss: 14.51238
# EPOCH 65:
# avg_loss: 14.50660
# EPOCH 66:
# avg_loss: 14.50531
# EPOCH 67:
# avg_loss: 14.49909
# EPOCH 68:
# avg_loss: 14.49280
# EPOCH 69:
# avg_loss: 14.48811
# EPOCH 70:
# avg_loss: 14.48739
# EPOCH 71:
# avg_loss: 14.49216
# EPOCH 72:
# avg_loss: 14.47358
# EPOCH 73:
# avg_loss: 14.44879
# EPOCH 74:
# avg_loss: 14.38620
# EPOCH 75:
# avg_loss: 14.33039
# EPOCH 76:
# avg_loss: 14.26659
# EPOCH 77:
# avg_loss: 14.19843
# EPOCH 78:
# avg_loss: 14.12977
# EPOCH 79:
# avg_loss: 14.07766
# EPOCH 80:
# avg_loss: 14.03487
# EPOCH 81:
# avg_loss: 13.98913
# EPOCH 82:
# avg_loss: 13.95095
# EPOCH 83:
# avg_loss: 13.93206
# EPOCH 84:
# avg_loss: 13.89985
# EPOCH 85:
# avg_loss: 13.87831
# EPOCH 86:
# avg_loss: 13.86342
# EPOCH 87:
# avg_loss: 13.86126
# EPOCH 88:
# avg_loss: 13.85273
# EPOCH 89:
# avg_loss: 13.83938
# EPOCH 90:
# avg_loss: 13.83144
# EPOCH 91:
# avg_loss: 13.81672
# EPOCH 92:
# avg_loss: 13.81645
# EPOCH 93:
# avg_loss: 13.80412
# EPOCH 94:
# avg_loss: 13.79004
# EPOCH 95:
# avg_loss: 13.77813
# EPOCH 96:
# avg_loss: 13.77571
# EPOCH 97:
# avg_loss: 13.75607
# EPOCH 98:
# avg_loss: 13.74494
# EPOCH 99:
# avg_loss: 13.73277
# EPOCH 100:
# avg_loss: 13.71826
# Execution time: 60.359035 seconds
# baseline average loss:  0.1636879387396303
# baseline repeat:  0.2250000053847378
# regression loss total:  0.14752289283515793
# model loss total:  0.1426369547843933
#
# regression loss predindex:  0.1887136872108646
# model loss predindex:  0.20713092386722565
